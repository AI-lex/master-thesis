# %% [markdown]
# <h1 align="center">Bibliotheken und Daten laden sowie Spark Session erzeugen</h1>

# %%
import pprint as pp
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf

from pyspark.ml import Pipeline
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.feature import VectorAssembler, OneHotEncoderEstimator, StringIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder


#https://mapr.com/blog/churn-prediction-sparkml/
#Vorgehen: Load -> Extract Feature -> Transformer -> Train Model -> Evaluator


spark = SparkSession\
    .builder\
    .master("local[*]")\
    .appName("random forest umsatzschaetzung")\
    .getOrCreate()


dateipfad = "C:\\Users\\AMeinert\\Documents\\Python_Scripts\\projects\\MA\\data\\share\\"
datei_selected_features = "selected_features.csv"

pd_data = pd.read_csv(dateipfad + datei_selected_features, sep=";")
data = spark.createDataFrame(pd_data)
#data = spark.read.csv(dateipfad + datei_selected_features, sep=";", inferSchema=True, encoding="ISO-8859-1", header=True)

# %%
data.printSchema()

# %%
data
# Out:
#       DEM_3_29  GEB_6_4  DEM_2_4   HH_4_4  WHG_4_2  osm_nodes_counter  \
# 0        217.0    376.0   4613.0   4088.0    608.0                254
# 1        384.0    707.0   8764.0   7090.0   1342.0                408
# 2          6.0      4.0    221.0    191.0     20.0                 17
# 3         21.0      9.0    435.0    283.0     33.0                 13
# 4         72.0    127.0   1493.0   1227.0    198.0                 65
# 5          6.0      NaN    238.0    180.0      9.0                 15
# 6         21.0     19.0    529.0    397.0     31.0                 22
# 7         11.0     12.0    295.0    199.0     18.0                 12
# 8          6.0      6.0    185.0    148.0      3.0                  5
# 9          7.0      3.0    430.0    325.0     12.0                 22
# 10         6.0      3.0    237.0    171.0     30.0                 12
# 11        80.0     45.0   1330.0    995.0     68.0                 91
# 12        18.0      3.0    337.0    220.0     11.0                 11
# 13        19.0      6.0    323.0    226.0      3.0                  7
# 14        57.0     54.0    788.0    773.0    221.0                113
# 15         6.0      NaN    346.0    261.0      3.0                 12
# 16         9.0     15.0    130.0     96.0      NaN                 18
# 17         9.0     13.0    308.0    266.0     18.0                 17
# 18       115.0    104.0   2070.0   1667.0    179.0                116
# 19        12.0      9.0    210.0    163.0      NaN                 19
# 20        10.0     17.0    324.0    181.0     24.0                  1
# 21        21.0      9.0    265.0    197.0     19.0                  2
# 22         3.0      4.0    262.0    166.0     14.0                  3
# 23         3.0      6.0    204.0    139.0     34.0                 17
# 24        49.0     37.0    747.0    539.0     65.0                 19
# 25         6.0      6.0    167.0    129.0     12.0                  5
# 26         NaN      9.0    220.0    183.0     13.0                  0
# 27        23.0     12.0    358.0    279.0     32.0                  1
# 28        16.0      7.0    355.0    265.0     16.0                  2
# 29        37.0     45.0    696.0    463.0     55.0                 37
# ...        ...      ...      ...      ...      ...                ...
# 9541      55.0     70.0    940.0    802.0    192.0                 51
# 9542      48.0     62.0    864.0    728.0     89.0                 11
# 9543     717.0   1379.0  11915.0  11706.0   3757.0                357
# 9544     112.0    107.0   1210.0   1151.0    426.0                 45
# 9545     243.0    516.0   3551.0   3387.0    640.0                103
# 9546      73.0     93.0   1171.0    992.0    140.0                 38
# 9547     241.0    492.0   4129.0   3782.0    988.0                166
# 9548      46.0     51.0   1066.0    866.0    205.0                 37
# 9549      16.0     29.0    406.0    326.0     70.0                 13
# 9550      12.0     15.0    155.0    130.0     18.0                  8
# 9551       9.0      9.0    141.0    141.0     27.0                  7
# 9552       9.0     10.0    192.0    159.0     33.0                  0
# 9553      45.0     39.0    632.0    507.0    144.0                 12
# 9554      16.0     33.0    270.0    254.0     74.0                 17
# 9555       3.0     12.0    171.0    184.0     48.0                  0
# 9556      14.0     53.0    303.0    254.0     77.0                  7
# 9557      27.0     46.0    399.0    330.0     56.0                  7
# 9558      36.0     62.0    672.0    636.0    288.0                 18
# 9559      22.0     50.0    362.0    339.0     47.0                  4
# 9560       3.0      6.0    218.0    220.0     15.0                  9
# 9561      13.0      3.0    152.0    118.0     29.0                  4
# 9562      62.0    152.0    996.0    901.0    180.0                 26
# 9563      26.0     56.0    704.0    509.0     68.0                 24
# 9564       9.0     15.0    291.0    226.0     31.0                 22
# 9565      17.0     15.0    371.0    289.0     81.0                 16
# 9566      23.0     25.0    289.0    251.0     78.0                 22
# 9567       9.0     10.0    152.0    144.0     13.0                  8
# 9568      10.0     16.0    201.0    148.0     13.0                 13
# 9569      82.0    229.0   1247.0   1100.0    350.0                 42
# 9570      30.0     50.0    514.0    474.0     59.0                 17
#
#       BEV_INSGESAMT  BEV_JE_QM  FLAECHE_QM  ANTEIL_ARBEITSLOSE      ...       \
# 0             13120        201       65.24                 8.4      ...
# 1             20886        653       31.97                 8.4      ...
# 2               599         66        9.07                 8.4      ...
# 3              1076         74       14.55                 8.4      ...
# 4              4237        377       11.23                 8.4      ...
# 5               670         95        7.02                 8.4      ...
# 6              1367        148        9.21                 8.4      ...
# 7               781         61       12.79                 8.4      ...
# 8               516         50       10.40                 8.4      ...
# 9              1234        226        5.46                 8.4      ...
# 10              652         57       11.36                 8.4      ...
# 11             3635        158       23.05                 8.4      ...
# 12              866         55       15.74                 8.4      ...
# 13              755        101        7.46                 8.4      ...
# 14             2452         46       53.35                 8.4      ...
# 15              946         83       11.44                 8.4      ...
# 16              375         29       13.06                 8.4      ...
# 17              892         31       28.85                 8.4      ...
# 18             5825       1206        4.83                 8.4      ...
# 19              620         60       10.41                 8.4      ...
# 20              788         36       21.77                 8.4      ...
# 21              717         45       15.84                 8.4      ...
# 22              635         81        7.82                 8.4      ...
# 23              544         33       16.53                 8.4      ...
# 24             1924         88       21.93                 8.4      ...
# 25              419         33       12.81                 8.4      ...
# 26              625        129        4.83                 8.4      ...
# 27             1063         57       18.63                 8.4      ...
# 28              854         73       11.62                 8.4      ...
# 29             1631        351        4.65                 8.4      ...
# ...             ...        ...         ...                 ...      ...
# 9541           2812        116       24.30                 9.2      ...
# 9542           2481         95       26.15                 9.2      ...
# 9543          34972        767       45.60                12.2      ...
# 9544           4086        315       12.99                12.2      ...
# 9545          11261        211       53.47                12.2      ...
# 9546           3561        127       27.93                12.2      ...
# 9547          11879        286       41.59                12.2      ...
# 9548           2999         70       42.73                12.2      ...
# 9549           1061         53       20.05                12.2      ...
# 9550            505         77        6.55                12.2      ...
# 9551            439         51        8.60                12.2      ...
# 9552            561         52       10.74                12.2      ...
# 9553           1904         80       23.66                12.2      ...
# 9554            852         96        8.83                12.2      ...
# 9555            538        172        3.13                12.2      ...
# 9556            833        303        2.75                12.2      ...
# 9557           1292        129       10.00                12.2      ...
# 9558           2097        101       20.72                12.2      ...
# 9559           1132         85       13.30                12.2      ...
# 9560            715        166        4.30                12.2      ...
# 9561            483         85        5.66                12.2      ...
# 9562           3050        241       12.65                12.2      ...
# 9563           1928         49       39.65                12.2      ...
# 9564            878         51       17.32                12.2      ...
# 9565           1084         65       16.73                12.2      ...
# 9566            935         93       10.01                12.2      ...
# 9567            464         84        5.54                12.2      ...
# 9568            590         63        9.44                12.2      ...
# 9569           3752        267       14.04                12.2      ...
# 9570           1684         99       17.04                12.2      ...
#
#       EINK_JE_EINW  WHG_6_5  BESIEDLUNGSSCHLUESSEL  REGIONSTYP  revenue_sum1  \
# 0          18912.0    317.0                      3       stadt    4787567.82
# 1          18912.0    323.0                      3       stadt   21176682.51
# 2          18912.0     17.0                      3         gem           NaN
# 3          18912.0     12.0                      3         gem           NaN
# 4          18912.0     96.0                      3         gem           NaN
# 5          18912.0      6.0                      3         gem           NaN
# 6          18912.0     28.0                      3         gem           NaN
# 7          18912.0     15.0                      3         gem           NaN
# 8          18912.0      9.0                      3         gem           NaN
# 9          18912.0     12.0                      3         gem           NaN
# 10         18912.0      9.0                      3         gem           NaN
# 11         18912.0     31.0                      3         gem           NaN
# 12         18912.0     11.0                      3         gem           NaN
# 13         18912.0     12.0                      3         gem           NaN
# 14         18912.0     67.0                      3         gem           NaN
# 15         18912.0     16.0                      3         gem           NaN
# 16         18912.0      3.0                      3         gem           NaN
# 17         18912.0     12.0                      3         gem           NaN
# 18         18912.0    107.0                      3       stadt    5525058.30
# 19         18912.0     12.0                      3         gem           NaN
# 20         18912.0     18.0                      3         gem           NaN
# 21         18912.0     15.0                      3         gem           NaN
# 22         18912.0      6.0                      3         gem           NaN
# 23         18912.0     14.0                      3         gem           NaN
# 24         18912.0     26.0                      3         gem           NaN
# 25         18912.0      3.0                      3         gem           NaN
# 26         18912.0     15.0                      3         gem           NaN
# 27         18912.0     10.0                      3         gem           NaN
# 28         18912.0      3.0                      3         gem           NaN
# 29         18912.0     44.0                      3         gem           NaN
# ...            ...      ...                    ...         ...           ...
# 9541       17212.0     72.0                      2         gem           NaN
# 9542       17212.0     94.0                      2         gem           NaN
# 9543       16360.0   3534.0                      2       stadt   12413497.61
# 9544       16360.0    491.0                      2       stadt           NaN
# 9545       16360.0    641.0                      2       stadt    3916230.41
# 9546       16360.0    121.0                      2         gem           NaN
# 9547       16360.0    595.0                      2       stadt    4696948.10
# 9548       16360.0    129.0                      3         gem           NaN
# 9549       16360.0     49.0                      3         gem           NaN
# 9550       16360.0     40.0                      3         gem           NaN
# 9551       16360.0     25.0                      3         gem           NaN
# 9552       16360.0     13.0                      3         gem           NaN
# 9553       16360.0     68.0                      3         gem           NaN
# 9554       16360.0     28.0                      2         gem           NaN
# 9555       16360.0     29.0                      2         gem           NaN
# 9556       16360.0     44.0                      2         gem           NaN
# 9557       16360.0     50.0                      2         gem           NaN
# 9558       16360.0     43.0                      2         gem           NaN
# 9559       16360.0     74.0                      3         gem           NaN
# 9560       16360.0     22.0                      2         gem     994451.00
# 9561       16360.0      9.0                      3         gem           NaN
# 9562       16360.0    192.0                      2         gem           NaN
# 9563       16360.0     62.0                      3         gem           NaN
# 9564       16360.0     31.0                      3         gem           NaN
# 9565       16360.0     17.0                      3         gem           NaN
# 9566       16360.0     30.0                      2         gem           NaN
# 9567       16360.0     19.0                      3         gem           NaN
# 9568       16360.0     26.0                      3         gem           NaN
# 9569       16360.0    334.0                      2       stadt           NaN
# 9570       16360.0     69.0                      2         gem           NaN
#
#      revenue_sum2  revenue_avg2  revenue_avg1_per_head  revenue_avg2_per_head  \
# 0      4787567.82    4787567.82                 364.91                 364.91
# 1     21176682.51   10588341.26                 506.96                 506.96
# 2             NaN           NaN                    NaN                    NaN
# 3             NaN           NaN                    NaN                    NaN
# 4             NaN           NaN                    NaN                    NaN
# 5             NaN           NaN                    NaN                    NaN
# 6             NaN           NaN                    NaN                    NaN
# 7             NaN           NaN                    NaN                    NaN
# 8             NaN           NaN                    NaN                    NaN
# 9             NaN           NaN                    NaN                    NaN
# 10            NaN           NaN                    NaN                    NaN
# 11            NaN           NaN                    NaN                    NaN
# 12            NaN           NaN                    NaN                    NaN
# 13            NaN           NaN                    NaN                    NaN
# 14            NaN           NaN                    NaN                    NaN
# 15            NaN           NaN                    NaN                    NaN
# 16            NaN           NaN                    NaN                    NaN
# 17            NaN           NaN                    NaN                    NaN
# 18     5525058.30    5525058.30                 948.51                 948.51
# 19            NaN           NaN                    NaN                    NaN
# 20            NaN           NaN                    NaN                    NaN
# 21            NaN           NaN                    NaN                    NaN
# 22            NaN           NaN                    NaN                    NaN
# 23            NaN           NaN                    NaN                    NaN
# 24            NaN           NaN                    NaN                    NaN
# 25            NaN           NaN                    NaN                    NaN
# 26            NaN           NaN                    NaN                    NaN
# 27            NaN           NaN                    NaN                    NaN
# 28            NaN           NaN                    NaN                    NaN
# 29            NaN           NaN                    NaN                    NaN
# ...           ...           ...                    ...                    ...
# 9541          NaN           NaN                    NaN                    NaN
# 9542          NaN           NaN                    NaN                    NaN
# 9543  12413497.61   12413497.61                 354.96                 354.96
# 9544          NaN           NaN                    NaN                    NaN
# 9545   3916230.41    3916230.41                 347.77                 347.77
# 9546          NaN           NaN                    NaN                    NaN
# 9547   4696948.10    4696948.10                 395.40                 395.40
# 9548          NaN           NaN                    NaN                    NaN
# 9549          NaN           NaN                    NaN                    NaN
# 9550          NaN           NaN                    NaN                    NaN
# 9551          NaN           NaN                    NaN                    NaN
# 9552          NaN           NaN                    NaN                    NaN
# 9553          NaN           NaN                    NaN                    NaN
# 9554          NaN           NaN                    NaN                    NaN
# 9555          NaN           NaN                    NaN                    NaN
# 9556          NaN           NaN                    NaN                    NaN
# 9557          NaN           NaN                    NaN                    NaN
# 9558          NaN           NaN                    NaN                    NaN
# 9559          NaN           NaN                    NaN                    NaN
# 9560    994451.00     994451.00                1390.84                1390.84
# 9561          NaN           NaN                    NaN                    NaN
# 9562          NaN           NaN                    NaN                    NaN
# 9563          NaN           NaN                    NaN                    NaN
# 9564          NaN           NaN                    NaN                    NaN
# 9565          NaN           NaN                    NaN                    NaN
# 9566          NaN           NaN                    NaN                    NaN
# 9567          NaN           NaN                    NaN                    NaN
# 9568          NaN           NaN                    NaN                    NaN
# 9569          NaN           NaN                    NaN                    NaN
# 9570          NaN           NaN                    NaN                    NaN
#
#       revenue_avg1
# 0       4787567.82
# 1      10588341.26
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18      5525058.30
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# ...            ...
# 9541           NaN
# 9542           NaN
# 9543   12413497.61
# 9544           NaN
# 9545    3916230.41
# 9546           NaN
# 9547    4696948.10
# 9548           NaN
# 9549           NaN
# 9550           NaN
# 9551           NaN
# 9552           NaN
# 9553           NaN
# 9554           NaN
# 9555           NaN
# 9556           NaN
# 9557           NaN
# 9558           NaN
# 9559           NaN
# 9560     994451.00
# 9561           NaN
# 9562           NaN
# 9563           NaN
# 9564           NaN
# 9565           NaN
# 9566           NaN
# 9567           NaN
# 9568           NaN
# 9569           NaN
# 9570           NaN
#
# [9571 rows x 22 columns]

# %% [markdown]
# <img src="https://mapr.com/blog/churn-prediction-sparkml/assets/Picture11.png">

# %% [markdown]
# <h1 align="center">KONFIGURATION DES MODELLS</h1>

# %% [markdown]
# Erklärung zu den Parametern des RandomForest Algos (Auszug Spark Dokumentation)
# <h2>Random Forest Tuning Parameters (hyperparameter-tuning)</h2>
# <div>The first two parameters we mention are the most important, and tuning them can often improve performance:
#
# <ul><b>numTrees</b>: Number of trees in the forest. Increasing the number of trees will decrease the variance in predictions,improving the model’s test-time accuracy. raining time increases roughly linearly in the number of trees.</ul>
#
# <ul><b>maxDepth</b>: Maximum depth of each tree in the forest. ncreasing the depth makes the model more expressive and powerful. However, deep trees take longer to train and are also more prone to overfitting. Ingeneral, it is acceptable to train deeper trees when using random forests than when using a single decision tree. One tree is more likely to overfit than a random forest (because of the variance reduction from averaging multiple trees in the forest).</ul>
# </div>
# <div>
# The next two parameters generally do not require tuning. However, they can be tuned to speed up training.
#
# <ul><b>subsamplingRate:</b> This parameter specifies the size of the dataset used for training each tree in the forest, as a fraction of the size of the original dataset. The default (1.0) is recommended, but decreasing this fraction can speed up training.</ul>
#
# <ul><b>featureSubsetStrategy:</b> Number of features to use as candidates for splitting at each tree node. The number is specified as a fraction or function of the total number of features. Decreasing this number will speed up training, but can sometimes impact performance if too low.</ul>
# </div>

# %%
test_set_size = 0.3
seed = 42

input_feat = ["DEM_3_29", 
              "GEB_6_4",
              "DEM_2_4",
              "HH_4_4",
              "WHG_4_2",
              "osm_nodes_counter",
              "BEV_INSGESAMT",
              "BEV_JE_QM",
              "FLAECHE_QM",
              "ANTEIL_ARBEITSLOSE",
              "ANTEIL_ARBEITSLOSE_ALTER_15_24",
              "ANTEIL_SIEDLUNG_VERKEHR",
              "EINK_JE_EINW",
              "WHG_6_5",
              "BESIEDLUNGSSCHLUESSEL",
              "REGIONSTYP"]

pred_col = "revenue_avg1"

rf = RandomForestRegressor(featuresCol="features", seed=seed)

"""
paramGrid = ParamGridBuilder()\
    .addGrid(rf.subsamplingRate, [0.7, 0.8, 0.9, 1.0])\
    .addGrid(rf.numTrees, [3, 4, 5, 6, 7, 10, 15, 30, 60, 120, 200])\
    .addGrid(rf.maxDepth, [2, 3, 4, 5, 6])\
    .addGrid(rf.featureSubsetStrategy, ["all", "onethird", "sqrt"])\
    .build()
"""
 
paramGrid = ParamGridBuilder()\
    .addGrid(rf.subsamplingRate, [0.7, 0.8, 0.9, 1.0])\
    .addGrid(rf.numTrees, [7, 15, 40, 70, 120, 150])\
    .addGrid(rf.maxDepth, [3, 5, 6])\
    .addGrid(rf.featureSubsetStrategy, ["all", "onethird"])\
    .build()
    

rf = RandomForestRegressor(featuresCol="features")

crossval = CrossValidator(estimator=rf,
                          estimatorParamMaps=paramGrid,
                          evaluator=RegressionEvaluator(metricName="r2"),
                          numFolds=3)

# %% [markdown]
# <h1 align="center">FEATURE TRANSFORMATION</h1>
# <ol>
#     <li>Überführung der kategorialen Variabeln in numerische Typen (StringIndexer)</li>
#     <li>Kategoriale Variablen (indexiert) in binäre Vektoren (OneHotEncoderEstimator)</li>
#     <li>Feature Vektor mit allen Merkmalen erzeugen (VektorAssembler)</li>
# </ol>

# %%
data_not_null = data.dropna(subset=input_feat)
print("Rows vor Eliminierung der Nullwerte: " + str(data.count()))
print("Rows nach Eliminierung der Nullwerte: " + str(data_not_null.count()))

## Umformung des Merkmals "Regionstyp" in eine numerische Darstellung
indexer = StringIndexer(inputCol="REGIONSTYP", outputCol="REGIONSTYP_INDEX")
data_index = indexer.fit(data).transform(data)

## Transformation der nun numerischen Merkmale "Besiedlungsschlüssel" und "Regionstyp" in einen binären Vektor
encoder = OneHotEncoder(inputCols=["BESIEDLUNGSSCHLUESSEL", "REGIONSTYP_INDEX"],
                    outputCols=["BESIEDLUNGSSCHLUESSEL_encoded", "REGIONSTYP_encoded"])

data_encoded = encoder.fit(data_indexed).transform(data_index)


## Transformation aller Features in einen Vektor
vector_assembler = VectorAssembler(inputCols=input_feat, outputCol="features")
data_vec = vector_assembler.transform(data_encoded)
# Out:
# Rows vor Eliminierung der Nullwerte: 9571
# Rows nach Eliminierung der Nullwerte: 9118
# +----------+----------------+
# |REGIONSTYP|REGIONSTYP_INDEX|
# +----------+----------------+
# |     stadt|             1.0|
# |     stadt|             1.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |     stadt|             1.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# |       gem|             0.0|
# +----------+----------------+
# only showing top 20 rows

# %%
encoder = OneHotEncoderEstimator(inputCols=["BESIEDLUNGSSCHLUESSEL", "REGIONSTYP_INDEX"],
                                 outputCols=["BESIEDLUNGSSCHLUESSEL_encoded", "REGIONSTYP_encoded"])

data_encoded = encoder.fit(data_indexed).transform(data_indexed)

# %%
data_encoded.select("BESIEDLUNGSSCHLUESSEL_encoded", "BESIEDLUNGSSCHLUESSEL", "REGIONSTYP_INDEX","REGIONSTYP_encoded").show()
# Out:
# +-----------------------------+---------------------+----------------+------------------+
# |BESIEDLUNGSSCHLUESSEL_encoded|BESIEDLUNGSSCHLUESSEL|REGIONSTYP_INDEX|REGIONSTYP_encoded|
# +-----------------------------+---------------------+----------------+------------------+
# |                    (3,[],[])|                    3|             1.0|         (1,[],[])|
# |                    (3,[],[])|                    3|             1.0|         (1,[],[])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             1.0|         (1,[],[])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# |                    (3,[],[])|                    3|             0.0|     (1,[0],[1.0])|
# +-----------------------------+---------------------+----------------+------------------+
# only showing top 20 rows

# %%
input_feat.remove("BESIEDLUNGSSCHLUESSEL")
input_feat.remove("REGIONSTYP")

input_feat.append("BESIEDLUNGSSCHLUESSEL_encoded")
input_feat.append("REGIONSTYP_encoded")
input_feat
# Out:
# ['DEM_3_29',
#  'GEB_6_4',
#  'DEM_2_4',
#  'HH_4_4',
#  'WHG_4_2',
#  'osm_nodes_counter',
#  'BEV_INSGESAMT',
#  'BEV_JE_QM',
#  'FLAECHE_QM',
#  'ANTEIL_ARBEITSLOSE',
#  'ANTEIL_ARBEITSLOSE_ALTER_15_24',
#  'ANTEIL_SIEDLUNG_VERKEHR',
#  'EINK_JE_EINW',
#  'WHG_6_5',
#  'BESIEDLUNGSSCHLUESSEL_encoded',
#  'REGIONSTYP_encoded']

# %%
data_vec.select("features").show(truncate= False)
data_vec.count()
# Out:
# +--------------------------------------------------------------------------------------------------------+
# |features                                                                                                |
# +--------------------------------------------------------------------------------------------------------+
# |[217.0,376.0,4613.0,4088.0,608.0,254.0,13120.0,201.0,65.24,8.4,13.6,10.9,18912.0,317.0,0.0,0.0,0.0,0.0] |
# |[384.0,707.0,8764.0,7090.0,1342.0,408.0,20886.0,653.0,31.97,8.4,13.6,10.9,18912.0,323.0,0.0,0.0,0.0,0.0]|
# |[6.0,4.0,221.0,191.0,20.0,17.0,599.0,66.0,9.07,8.4,13.6,10.9,18912.0,17.0,0.0,0.0,0.0,1.0]              |
# |[21.0,9.0,435.0,283.0,33.0,13.0,1076.0,74.0,14.55,8.4,13.6,10.9,18912.0,12.0,0.0,0.0,0.0,1.0]           |
# |[72.0,127.0,1493.0,1227.0,198.0,65.0,4237.0,377.0,11.23,8.4,13.6,10.9,18912.0,96.0,0.0,0.0,0.0,1.0]     |
# |[21.0,19.0,529.0,397.0,31.0,22.0,1367.0,148.0,9.21,8.4,13.6,10.9,18912.0,28.0,0.0,0.0,0.0,1.0]          |
# |[11.0,12.0,295.0,199.0,18.0,12.0,781.0,61.0,12.79,8.4,13.6,10.9,18912.0,15.0,0.0,0.0,0.0,1.0]           |
# |[6.0,6.0,185.0,148.0,3.0,5.0,516.0,50.0,10.4,8.4,13.6,10.9,18912.0,9.0,0.0,0.0,0.0,1.0]                 |
# |[7.0,3.0,430.0,325.0,12.0,22.0,1234.0,226.0,5.46,8.4,13.6,10.9,18912.0,12.0,0.0,0.0,0.0,1.0]            |
# |[6.0,3.0,237.0,171.0,30.0,12.0,652.0,57.0,11.36,8.4,13.6,10.9,18912.0,9.0,0.0,0.0,0.0,1.0]              |
# |[80.0,45.0,1330.0,995.0,68.0,91.0,3635.0,158.0,23.05,8.4,13.6,10.9,18912.0,31.0,0.0,0.0,0.0,1.0]        |
# |[18.0,3.0,337.0,220.0,11.0,11.0,866.0,55.0,15.74,8.4,13.6,10.9,18912.0,11.0,0.0,0.0,0.0,1.0]            |
# |[19.0,6.0,323.0,226.0,3.0,7.0,755.0,101.0,7.46,8.4,13.6,10.9,18912.0,12.0,0.0,0.0,0.0,1.0]              |
# |[57.0,54.0,788.0,773.0,221.0,113.0,2452.0,46.0,53.35,8.4,13.6,10.9,18912.0,67.0,0.0,0.0,0.0,1.0]        |
# |[9.0,13.0,308.0,266.0,18.0,17.0,892.0,31.0,28.85,8.4,13.6,10.9,18912.0,12.0,0.0,0.0,0.0,1.0]            |
# |[115.0,104.0,2070.0,1667.0,179.0,116.0,5825.0,1206.0,4.83,8.4,13.6,10.9,18912.0,107.0,0.0,0.0,0.0,0.0]  |
# |[10.0,17.0,324.0,181.0,24.0,1.0,788.0,36.0,21.77,8.4,13.6,10.9,18912.0,18.0,0.0,0.0,0.0,1.0]            |
# |[21.0,9.0,265.0,197.0,19.0,2.0,717.0,45.0,15.84,8.4,13.6,10.9,18912.0,15.0,0.0,0.0,0.0,1.0]             |
# |[3.0,4.0,262.0,166.0,14.0,3.0,635.0,81.0,7.82,8.4,13.6,10.9,18912.0,6.0,0.0,0.0,0.0,1.0]                |
# |[3.0,6.0,204.0,139.0,34.0,17.0,544.0,33.0,16.53,8.4,13.6,10.9,18912.0,14.0,0.0,0.0,0.0,1.0]             |
# +--------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
# 9118

# %% [markdown]
# <h1 align="center"> TEST UND TRAININGS DATEN ERZEUGEN</h1>

# %%
vorhersagedaten = data_vec.select("*").where(col(pred_col).isNull())
lerndaten = data_vec.select("*").where(col(pred_col).isNotNull()).withColumnRenamed(pred_col, "label")

training, test = lerndaten.randomSplit([0.7 , 0.3])

cvModel = crossval.fit(training)



display(
    "Rows im gesamten Datensatz:  " + str(data.count()),
    "Rows im Learning-Datensatz:  " + str(learning_data.count()),
    "      Rows im Trainings-Datensatz:  " + str(training.count()),
    "      Rows im Test-Datensatz:       " + str(test.count()),
    "Rows im Prediction-Datensatz: " + str(prediction_data.count())
)
# Out:
# 'Rows im gesamten Datensatz:  9571'
# 'Rows im Learning-Datensatz:  1825'
# '      Rows im Trainings-Datensatz:  1266'
# '      Rows im Test-Datensatz:       559'
# 'Rows im Prediction-Datensatz: 7293'

# %% [markdown]
# <h1 align="center"> BESTES MODEL AUSWÄHLEN (CrossValidator) UND VALIDIEREN </h1>

# %%
cvModel = crossval.fit(training)

for i in range(15):
    key = list(cvModel.bestModel.extractParamMap().keys())[i].name
    value = list(cvModel.bestModel.extractParamMap().values())[i]
    print(str(key) + " " + str(value))
# Out:
# cacheNodeIds False
# checkpointInterval 10
# featureSubsetStrategy all
# featuresCol features
# impurity variance
# labelCol label
# maxBins 32
# maxDepth 5
# maxMemoryInMB 256
# minInfoGain 0.0
# minInstancesPerNode 1
# numTrees 120
# predictionCol prediction
# seed 42
# subsamplingRate 0.8

# %%
numTrees = 120
maxDepth = 5
maxBins = 32
featureSubsetStrategy = "all" #one-all, sqrt,...
impurity = "variance" #gini
subsamplingRate = 0.8

# %%
pipeline = Pipeline(stages=[vector_assembler, rf])

model = pipeline.fit(training.drop("features"))
rfModel = model.stages[1]

rf = RandomForestRegressor(featuresCol="features", seed=seed, numTrees=numTrees, maxDepth=maxDepth, maxBins=maxBins,
                          featureSubsetStrategy=featureSubsetStrategy, impurity=impurity, subsamplingRate=subsamplingRate)

# %%
validation = model.transform(test.drop("features"))

validation.select("prediction", "label", "features").show(5)


metrics_vali = {}
importance = {}

for metric in ["mae", "mse", "rmse", "r2"]:
    evaluator = RegressionEvaluator(
    labelCol="label", predictionCol="prediction", metricName=metric)
    metric_value = evaluator.evaluate(validation)
    metrics_vali.update({metric: str(round(metric_value,2))})

    
metrics = pd.DataFrame(data=list(metrics_vali.values()), index=list(metrics_vali.keys()))
display(metrics.transpose())    

for i in range(len(rfModel.featureImportances)):
    #print( + " " + str(rfModel.featureImportances[i]))
    importance.update({test.columns[i]: rfModel.featureImportances[i]})
    
    

pp.pprint(metrics_vali)    
rfModel.extractParamMap() 
#rfModel.explainParams() 

pd.Series(index=importance.keys(), data=importance).plot(kind="bar", title="Importance Factor of Input Variables", figsize=(10, 5))

validation.toPandas().sort_values(by=["label"]).reset_index().plot(title="prediction/label testset", y=["prediction", "label"], figsize=(10, 5))
# Out:
# +------------------+----------+--------------------+
# |        prediction|     label|            features|
# +------------------+----------+--------------------+
# | 2172086.587998198| 426378.41|[3.0,14.0,113.0,8...|
# | 2306869.762048066|1708572.58|[6.0,12.0,307.0,2...|
# |3112725.5009593805|2940454.81|[6.0,43.0,299.0,3...|
# | 2306869.762048066|1853099.44|[21.0,32.0,715.0,...|
# | 2435043.280035175|2008771.78|[23.0,7.0,485.0,3...|
# +------------------+----------+--------------------+
# only showing top 5 rows
#           mae               mse        rmse    r2
# 0  1061522.17  2067673400040.05  1437940.68  0.91
# {'mae': '1061522.17',
#  'mse': '2067673400040.05',
#  'r2': '0.91',
#  'rmse': '1437940.68'}
# C:\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
# Out:
#           mae               mse        rmse    r2
# 0  1061522.17  2067673400040.05  1437940.68  0.91

# %%
rfModel.featureImportances
# Out:
# SparseVector(18, {0: 0.0443, 1: 0.0914, 2: 0.0484, 3: 0.0479, 4: 0.2536, 5: 0.4052, 6: 0.0385, 7: 0.0293, 8: 0.0074, 9: 0.0037, 10: 0.0036, 11: 0.0049, 12: 0.0125, 13: 0.0007, 15: 0.0065, 16: 0.001, 17: 0.0011})

# %%
validation.select("label", "prediction").toPandas().describe()
# Out:
#               label    prediction
# count  5.590000e+02  5.590000e+02
# mean   7.667166e+06  7.672591e+06
# std    4.698143e+06  4.005639e+06
# min    4.263784e+05  2.172087e+06
# 25%    4.390467e+06  4.630541e+06
# 50%    6.593357e+06  6.924262e+06
# 75%    9.590947e+06  9.530365e+06
# max    2.873314e+07  2.160806e+07

# %%
pp.pprint(model.stages[1].toDebugString)
# Out:
# ('RandomForestRegressionModel (uid=RandomForestRegressor_4c7c826d77b256cb6453) '
#  'with 20 trees\n'
#  '  Tree 0 (weight 1.0):\n'
#  '    If (feature 3 <= 5752.5)\n'
#  '     If (feature 5 <= 240.5)\n'
#  '      If (feature 5 <= 123.5)\n'
#  '       If (feature 7 <= 397.5)\n'
#  '        If (feature 3 <= 1105.5)\n'
#  '         Predict: 2007585.1156000001\n'
#  '        Else (feature 3 > 1105.5)\n'
#  '         Predict: 3107149.4410096155\n'
#  '       Else (feature 7 > 397.5)\n'
#  '        If (feature 7 <= 719.5)\n'
#  '         Predict: 4415730.7609375\n'
#  '        Else (feature 7 > 719.5)\n'
#  '         Predict: 6057112.038823529\n'
#  '      Else (feature 5 > 123.5)\n'
#  '       If (feature 4 <= 1229.0)\n'
#  '        If (feature 7 <= 211.5)\n'
#  '         Predict: 4216794.540130719\n'
#  '        Else (feature 7 > 211.5)\n'
#  '         Predict: 5546751.799186989\n'
#  '       Else (feature 4 > 1229.0)\n'
#  '        If (feature 4 <= 2296.5)\n'
#  '         Predict: 6827803.8883076925\n'
#  '        Else (feature 4 > 2296.5)\n'
#  '         Predict: 1.0924230070000002E7\n'
#  '     Else (feature 5 > 240.5)\n'
#  '      If (feature 12 <= 16366.5)\n'
#  '       If (feature 1 <= 207.5)\n'
#  '        If (feature 6 <= 5757.5)\n'
#  '         Predict: 5129496.64\n'
#  '        Else (feature 6 > 5757.5)\n'
#  '         Predict: 2.3116650472857144E7\n'
#  '       Else (feature 1 > 207.5)\n'
#  '        If (feature 10 <= 9.350000000000001)\n'
#  '         Predict: 5581173.13\n'
#  '        Else (feature 10 > 9.350000000000001)\n'
#  '         Predict: 7802078.929999999\n'
#  '      Else (feature 12 > 16366.5)\n'
#  '       If (feature 5 <= 749.0)\n'
#  '        If (feature 12 <= 21921.0)\n'
#  '         Predict: 7706446.458352942\n'
#  '        Else (feature 12 > 21921.0)\n'
#  '         Predict: 9811873.36630769\n'
#  '       Else (feature 5 > 749.0)\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 1.2814882516428571E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 1.9083686061250005E7\n'
#  '    Else (feature 3 > 5752.5)\n'
#  '     If (feature 5 <= 623.5)\n'
#  '      If (feature 4 <= 3764.5)\n'
#  '       If (feature 1 <= 707.5)\n'
#  '        If (feature 5 <= 423.5)\n'
#  '         Predict: 8214404.79716216\n'
#  '        Else (feature 5 > 423.5)\n'
#  '         Predict: 1.0620267189310346E7\n'
#  '       Else (feature 1 > 707.5)\n'
#  '        If (feature 2 <= 16816.0)\n'
#  '         Predict: 1.0484330309215683E7\n'
#  '        Else (feature 2 > 16816.0)\n'
#  '         Predict: 1.522378138166666E7\n'
#  '      Else (feature 4 > 3764.5)\n'
#  '       If (feature 10 <= 6.75)\n'
#  '        If (feature 5 <= 296.5)\n'
#  '         Predict: 1.36548067E7\n'
#  '        Else (feature 5 > 296.5)\n'
#  '         Predict: 1.9654690196666665E7\n'
#  '       Else (feature 10 > 6.75)\n'
#  '        If (feature 6 <= 24453.5)\n'
#  '         Predict: 1.012817361764706E7\n'
#  '        Else (feature 6 > 24453.5)\n'
#  '         Predict: 1.4008741884464284E7\n'
#  '     Else (feature 5 > 623.5)\n'
#  '      If (feature 7 <= 424.5)\n'
#  '       If (feature 9 <= 5.55)\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 1.6182254963157896E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 2.2288887732000005E7\n'
#  '       Else (feature 9 > 5.55)\n'
#  '        If (feature 7 <= 239.5)\n'
#  '         Predict: 1.2244058969999999E7\n'
#  '        Else (feature 7 > 239.5)\n'
#  '         Predict: 1.4409127901666671E7\n'
#  '      Else (feature 7 > 424.5)\n'
#  '       If (feature 3 <= 13913.5)\n'
#  '        If (feature 12 <= 20597.5)\n'
#  '         Predict: 1.7405096900625E7\n'
#  '        Else (feature 12 > 20597.5)\n'
#  '         Predict: 2.1284132830999997E7\n'
#  '       Else (feature 3 > 13913.5)\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 2.105955737E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 2.5263616288000003E7\n'
#  '  Tree 1 (weight 1.0):\n'
#  '    If (feature 4 <= 1587.5)\n'
#  '     If (feature 5 <= 318.0)\n'
#  '      If (feature 5 <= 123.5)\n'
#  '       If (feature 1 <= 159.5)\n'
#  '        If (feature 0 <= 86.5)\n'
#  '         Predict: 2280459.12144\n'
#  '        Else (feature 0 > 86.5)\n'
#  '         Predict: 3280129.1182291675\n'
#  '       Else (feature 1 > 159.5)\n'
#  '        If (feature 8 <= 14.350000000000001)\n'
#  '         Predict: 6089472.383636364\n'
#  '        Else (feature 8 > 14.350000000000001)\n'
#  '         Predict: 3655437.144285714\n'
#  '      Else (feature 5 > 123.5)\n'
#  '       If (feature 15 in {0.0})\n'
#  '        If (feature 6 <= 7584.0)\n'
#  '         Predict: 4226932.266\n'
#  '        Else (feature 6 > 7584.0)\n'
#  '         Predict: 5465669.12063158\n'
#  '       Else (feature 15 not in {0.0})\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 7072128.500857143\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 1.2070246260000005E7\n'
#  '     Else (feature 5 > 318.0)\n'
#  '      If (feature 4 <= 427.5)\n'
#  '       If (feature 16 in {1.0})\n'
#  '        If (feature 2 <= 2832.5)\n'
#  '         Predict: 8336931.68\n'
#  '        Else (feature 2 > 2832.5)\n'
#  '         Predict: 6718892.079999998\n'
#  '       Else (feature 16 not in {1.0})\n'
#  '        Predict: 2.4327953485E7\n'
#  '      Else (feature 4 > 427.5)\n'
#  '       If (feature 3 <= 2666.0)\n'
#  '        If (feature 12 <= 20442.5)\n'
#  '         Predict: 6811624.737142856\n'
#  '        Else (feature 12 > 20442.5)\n'
#  '         Predict: 8869351.323333332\n'
#  '       Else (feature 3 > 2666.0)\n'
#  '        If (feature 2 <= 4135.5)\n'
#  '         Predict: 1.2807721823333332E7\n'
#  '        Else (feature 2 > 4135.5)\n'
#  '         Predict: 9144481.373052632\n'
#  '    Else (feature 4 > 1587.5)\n'
#  '     If (feature 0 <= 503.5)\n'
#  '      If (feature 5 <= 623.5)\n'
#  '       If (feature 5 <= 366.5)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 8360100.945882352\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 1.4112290988461532E7\n'
#  '       Else (feature 5 > 366.5)\n'
#  '        If (feature 10 <= 7.35)\n'
#  '         Predict: 1.4069254496000001E7\n'
#  '        Else (feature 10 > 7.35)\n'
#  '         Predict: 1.0849666838428572E7\n'
#  '      Else (feature 5 > 623.5)\n'
#  '       If (feature 9 <= 5.05)\n'
#  '        If (feature 10 <= 10.95)\n'
#  '         Predict: 1.73933933E7\n'
#  '        Else (feature 10 > 10.95)\n'
#  '         Predict: 2.1360735120000005E7\n'
#  '       Else (feature 9 > 5.05)\n'
#  '        If (feature 8 <= 72.475)\n'
#  '         Predict: 1.5017660581875E7\n'
#  '        Else (feature 8 > 72.475)\n'
#  '         Predict: 1.2174858066666672E7\n'
#  '     Else (feature 0 > 503.5)\n'
#  '      If (feature 5 <= 623.5)\n'
#  '       If (feature 4 <= 4352.0)\n'
#  '        If (feature 7 <= 314.5)\n'
#  '         Predict: 9772027.537894735\n'
#  '        Else (feature 7 > 314.5)\n'
#  '         Predict: 1.2317553043684209E7\n'
#  '       Else (feature 4 > 4352.0)\n'
#  '        If (feature 10 <= 8.149999999999999)\n'
#  '         Predict: 1.8661118718333334E7\n'
#  '        Else (feature 10 > 8.149999999999999)\n'
#  '         Predict: 1.4357641802105263E7\n'
#  '      Else (feature 5 > 623.5)\n'
#  '       If (feature 12 <= 20442.5)\n'
#  '        If (feature 10 <= 11.05)\n'
#  '         Predict: 1.5349838416842107E7\n'
#  '        Else (feature 10 > 11.05)\n'
#  '         Predict: 2.21498888275E7\n'
#  '       Else (feature 12 > 20442.5)\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 1.9075552137083333E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 2.2736422596111108E7\n'
#  '  Tree 2 (weight 1.0):\n'
#  '    If (feature 5 <= 393.5)\n'
#  '     If (feature 1 <= 297.5)\n'
#  '      If (feature 4 <= 735.5)\n'
#  '       If (feature 5 <= 102.5)\n'
#  '        If (feature 5 <= 56.5)\n'
#  '         Predict: 2125292.9829999995\n'
#  '        Else (feature 5 > 56.5)\n'
#  '         Predict: 2834751.9917322826\n'
#  '       Else (feature 5 > 102.5)\n'
#  '        If (feature 1 <= 178.5)\n'
#  '         Predict: 4177860.594251969\n'
#  '        Else (feature 1 > 178.5)\n'
#  '         Predict: 4660652.418541667\n'
#  '      Else (feature 4 > 735.5)\n'
#  '       If (feature 15 in {0.0})\n'
#  '        If (feature 4 <= 1430.5)\n'
#  '         Predict: 5119449.6479338845\n'
#  '        Else (feature 4 > 1430.5)\n'
#  '         Predict: 6649176.784000004\n'
#  '       Else (feature 15 not in {0.0})\n'
#  '        If (feature 7 <= 719.5)\n'
#  '         Predict: 4968433.921250001\n'
#  '        Else (feature 7 > 719.5)\n'
#  '         Predict: 8486309.195714284\n'
#  '     Else (feature 1 > 297.5)\n'
#  '      If (feature 3 <= 5041.5)\n'
#  '       If (feature 12 <= 21060.0)\n'
#  '        If (feature 5 <= 240.5)\n'
#  '         Predict: 5145825.13359375\n'
#  '        Else (feature 5 > 240.5)\n'
#  '         Predict: 6737957.838500003\n'
#  '       Else (feature 12 > 21060.0)\n'
#  '        If (feature 5 <= 275.5)\n'
#  '         Predict: 7044981.098870967\n'
#  '        Else (feature 5 > 275.5)\n'
#  '         Predict: 9165792.884333335\n'
#  '      Else (feature 3 > 5041.5)\n'
#  '       If (feature 7 <= 987.5)\n'
#  '        If (feature 6 <= 45134.5)\n'
#  '         Predict: 8463061.6886\n'
#  '        Else (feature 6 > 45134.5)\n'
#  '         Predict: 1.436011213166666E7\n'
#  '       Else (feature 7 > 987.5)\n'
#  '        If (feature 1 <= 316.5)\n'
#  '         Predict: 1.07533725E7\n'
#  '        Else (feature 1 > 316.5)\n'
#  '         Predict: 1.4110798045833334E7\n'
#  '    Else (feature 5 > 393.5)\n'
#  '     If (feature 4 <= 5590.5)\n'
#  '      If (feature 5 <= 749.0)\n'
#  '       If (feature 4 <= 2970.0)\n'
#  '        If (feature 7 <= 239.5)\n'
#  '         Predict: 9318511.539859155\n'
#  '        Else (feature 7 > 239.5)\n'
#  '         Predict: 1.0702172146329114E7\n'
#  '       Else (feature 4 > 2970.0)\n'
#  '        If (feature 11 <= 15.25)\n'
#  '         Predict: 1.2291577208965516E7\n'
#  '        Else (feature 11 > 15.25)\n'
#  '         Predict: 1.4284446195128206E7\n'
#  '      Else (feature 5 > 749.0)\n'
#  '       If (feature 4 <= 556.0)\n'
#  '        If (feature 12 <= 18910.0)\n'
#  '         Predict: 2.571984347666667E7\n'
#  '        Else (feature 12 > 18910.0)\n'
#  '         Predict: 1.137647686E7\n'
#  '       Else (feature 4 > 556.0)\n'
#  '        If (feature 12 <= 19406.5)\n'
#  '         Predict: 1.4084609268636363E7\n'
#  '        Else (feature 12 > 19406.5)\n'
#  '         Predict: 1.762283425891892E7\n'
#  '     Else (feature 4 > 5590.5)\n'
#  '      If (feature 11 <= 15.75)\n'
#  '       If (feature 0 <= 799.5)\n'
#  '        If (feature 13 <= 430.5)\n'
#  '         Predict: 1.348292533E7\n'
#  '        Else (feature 13 > 430.5)\n'
#  '         Predict: 1.6728756496000001E7\n'
#  '       Else (feature 0 > 799.5)\n'
#  '        If (feature 9 <= 4.35)\n'
#  '         Predict: 1.754989216333333E7\n'
#  '        Else (feature 9 > 4.35)\n'
#  '         Predict: 2.001471939E7\n'
#  '      Else (feature 11 > 15.75)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 13 <= 659.5)\n'
#  '         Predict: 2.0447982338888887E7\n'
#  '        Else (feature 13 > 659.5)\n'
#  '         Predict: 1.819984784857143E7\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 1 <= 1451.0)\n'
#  '         Predict: 2.7768203E7\n'
#  '        Else (feature 1 > 1451.0)\n'
#  '         Predict: 2.5052002839999996E7\n'
#  '  Tree 3 (weight 1.0):\n'
#  '    If (feature 4 <= 1587.5)\n'
#  '     If (feature 1 <= 178.5)\n'
#  '      If (feature 5 <= 102.5)\n'
#  '       If (feature 7 <= 538.5)\n'
#  '        If (feature 5 <= 40.5)\n'
#  '         Predict: 1767919.1888235293\n'
#  '        Else (feature 5 > 40.5)\n'
#  '         Predict: 2694233.8915702472\n'
#  '       Else (feature 7 > 538.5)\n'
#  '        If (feature 9 <= 5.85)\n'
#  '         Predict: 4345167.2325\n'
#  '        Else (feature 9 > 5.85)\n'
#  '         Predict: 6691674.8500000015\n'
#  '      Else (feature 5 > 102.5)\n'
#  '       If (feature 15 in {0.0})\n'
#  '        If (feature 5 <= 193.5)\n'
#  '         Predict: 3823938.8813725496\n'
#  '        Else (feature 5 > 193.5)\n'
#  '         Predict: 5494216.218846152\n'
#  '       Else (feature 15 not in {0.0})\n'
#  '        If (feature 7 <= 719.5)\n'
#  '         Predict: 5468887.871666666\n'
#  '        Else (feature 7 > 719.5)\n'
#  '         Predict: 7270522.440000001\n'
#  '     Else (feature 1 > 178.5)\n'
#  '      If (feature 1 <= 316.5)\n'
#  '       If (feature 8 <= 7.895)\n'
#  '        If (feature 6 <= 7584.0)\n'
#  '         Predict: 6926928.546666667\n'
#  '        Else (feature 6 > 7584.0)\n'
#  '         Predict: 1.0682263355714282E7\n'
#  '       Else (feature 8 > 7.895)\n'
#  '        If (feature 8 <= 126.83)\n'
#  '         Predict: 5114158.004854771\n'
#  '        Else (feature 8 > 126.83)\n'
#  '         Predict: 6974275.319677422\n'
#  '      Else (feature 1 > 316.5)\n'
#  '       If (feature 4 <= 735.5)\n'
#  '        If (feature 8 <= 148.555)\n'
#  '         Predict: 5944626.5075\n'
#  '        Else (feature 8 > 148.555)\n'
#  '         Predict: 3581587.3674999997\n'
#  '       Else (feature 4 > 735.5)\n'
#  '        If (feature 5 <= 423.5)\n'
#  '         Predict: 6835416.018580247\n'
#  '        Else (feature 5 > 423.5)\n'
#  '         Predict: 1.0002166027600002E7\n'
#  '    Else (feature 4 > 1587.5)\n'
#  '     If (feature 5 <= 749.0)\n'
#  '      If (feature 3 <= 10259.5)\n'
#  '       If (feature 5 <= 423.5)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 8935602.558546513\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 1.3592766675999999E7\n'
#  '       Else (feature 5 > 423.5)\n'
#  '        If (feature 4 <= 3323.0)\n'
#  '         Predict: 1.1245436092537312E7\n'
#  '        Else (feature 4 > 3323.0)\n'
#  '         Predict: 1.4237999227083331E7\n'
#  '      Else (feature 3 > 10259.5)\n'
#  '       If (feature 6 <= 45134.5)\n'
#  '        If (feature 8 <= 49.565)\n'
#  '         Predict: 1.4920951966153843E7\n'
#  '        Else (feature 8 > 49.565)\n'
#  '         Predict: 1.1710517432647064E7\n'
#  '       Else (feature 6 > 45134.5)\n'
#  '        If (feature 5 <= 423.5)\n'
#  '         Predict: 1.3522933361666666E7\n'
#  '        Else (feature 5 > 423.5)\n'
#  '         Predict: 1.611954535318182E7\n'
#  '     Else (feature 5 > 749.0)\n'
#  '      If (feature 5 <= 956.0)\n'
#  '       If (feature 8 <= 34.425)\n'
#  '        If (feature 4 <= 5590.5)\n'
#  '         Predict: 1.8957096119999997E7\n'
#  '        Else (feature 4 > 5590.5)\n'
#  '         Predict: 2.564578969000001E7\n'
#  '       Else (feature 8 > 34.425)\n'
#  '        If (feature 12 <= 21692.0)\n'
#  '         Predict: 1.5060146205384614E7\n'
#  '        Else (feature 12 > 21692.0)\n'
#  '         Predict: 1.8168241671666667E7\n'
#  '      Else (feature 5 > 956.0)\n'
#  '       If (feature 6 <= 38629.0)\n'
#  '        If (feature 9 <= 5.05)\n'
#  '         Predict: 2.0546163977857146E7\n'
#  '        Else (feature 9 > 5.05)\n'
#  '         Predict: 1.4010476435000002E7\n'
#  '       Else (feature 6 > 38629.0)\n'
#  '        If (feature 8 <= 43.644999999999996)\n'
#  '         Predict: 3.170427334E7\n'
#  '        Else (feature 8 > 43.644999999999996)\n'
#  '         Predict: 2.3606487906363633E7\n'
#  '  Tree 4 (weight 1.0):\n'
#  '    If (feature 4 <= 1587.5)\n'
#  '     If (feature 3 <= 2482.5)\n'
#  '      If (feature 4 <= 628.5)\n'
#  '       If (feature 1 <= 80.5)\n'
#  '        If (feature 1 <= 54.5)\n'
#  '         Predict: 1823655.943043478\n'
#  '        Else (feature 1 > 54.5)\n'
#  '         Predict: 2641040.473571428\n'
#  '       Else (feature 1 > 80.5)\n'
#  '        If (feature 5 <= 113.5)\n'
#  '         Predict: 2830063.7478688527\n'
#  '        Else (feature 5 > 113.5)\n'
#  '         Predict: 4250627.799200001\n'
#  '      Else (feature 4 > 628.5)\n'
#  '       If (feature 8 <= 29.025)\n'
#  '        If (feature 1 <= 368.5)\n'
#  '         Predict: 5901137.145208333\n'
#  '        Else (feature 1 > 368.5)\n'
#  '         Predict: 9072473.739999989\n'
#  '       Else (feature 8 > 29.025)\n'
#  '        If (feature 4 <= 1040.0)\n'
#  '         Predict: 3930124.6649999996\n'
#  '        Else (feature 4 > 1040.0)\n'
#  '         Predict: 6993432.609999999\n'
#  '     Else (feature 3 > 2482.5)\n'
#  '      If (feature 0 <= 258.5)\n'
#  '       If (feature 4 <= 1326.5)\n'
#  '        If (feature 2 <= 3209.0)\n'
#  '         Predict: 7608380.0160869565\n'
#  '        Else (feature 2 > 3209.0)\n'
#  '         Predict: 5259734.58519651\n'
#  '       Else (feature 4 > 1326.5)\n'
#  '        If (feature 5 <= 458.0)\n'
#  '         Predict: 7367530.566666667\n'
#  '        Else (feature 5 > 458.0)\n'
#  '         Predict: 1.6902808563333333E7\n'
#  '      Else (feature 0 > 258.5)\n'
#  '       If (feature 1 <= 368.5)\n'
#  '        If (feature 11 <= 11.05)\n'
#  '         Predict: 8966345.64375\n'
#  '        Else (feature 11 > 11.05)\n'
#  '         Predict: 5143471.309444444\n'
#  '       Else (feature 1 > 368.5)\n'
#  '        If (feature 0 <= 503.5)\n'
#  '         Predict: 7801558.041734693\n'
#  '        Else (feature 0 > 503.5)\n'
#  '         Predict: 1.1892555629999995E7\n'
#  '    Else (feature 4 > 1587.5)\n'
#  '     If (feature 15 in {0.0})\n'
#  '      If (feature 4 <= 3323.0)\n'
#  '       If (feature 3 <= 6701.0)\n'
#  '        If (feature 8 <= 126.83)\n'
#  '         Predict: 8898923.208777774\n'
#  '        Else (feature 8 > 126.83)\n'
#  '         Predict: 1.2599856379999995E7\n'
#  '       Else (feature 3 > 6701.0)\n'
#  '        If (feature 12 <= 20800.0)\n'
#  '         Predict: 1.1083118265342467E7\n'
#  '        Else (feature 12 > 20800.0)\n'
#  '         Predict: 1.3326451279655164E7\n'
#  '      Else (feature 4 > 3323.0)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 3 <= 8011.5)\n'
#  '         Predict: 1.0381652149473686E7\n'
#  '        Else (feature 3 > 8011.5)\n'
#  '         Predict: 1.3136097913333334E7\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 8 <= 68.39)\n'
#  '         Predict: 1.776828841E7\n'
#  '        Else (feature 8 > 68.39)\n'
#  '         Predict: 2.356909998E7\n'
#  '     Else (feature 15 not in {0.0})\n'
#  '      If (feature 2 <= 14255.5)\n'
#  '       If (feature 2 <= 8378.5)\n'
#  '        If (feature 10 <= 8.649999999999999)\n'
#  '         Predict: 1.119203133548387E7\n'
#  '        Else (feature 10 > 8.649999999999999)\n'
#  '         Predict: 9390090.067241376\n'
#  '       Else (feature 2 > 8378.5)\n'
#  '        If (feature 5 <= 347.5)\n'
#  '         Predict: 1.0199059005E7\n'
#  '        Else (feature 5 > 347.5)\n'
#  '         Predict: 1.441533113131579E7\n'
#  '      Else (feature 2 > 14255.5)\n'
#  '       If (feature 10 <= 10.75)\n'
#  '        If (feature 10 <= 10.55)\n'
#  '         Predict: 1.8828599215217393E7\n'
#  '        Else (feature 10 > 10.55)\n'
#  '         Predict: 2.4309152920000017E7\n'
#  '       Else (feature 10 > 10.75)\n'
#  '        If (feature 10 <= 11.05)\n'
#  '         Predict: 1.5716727635000002E7\n'
#  '        Else (feature 10 > 11.05)\n'
#  '         Predict: 1.9609158409999996E7\n'
#  '  Tree 5 (weight 1.0):\n'
#  '    If (feature 5 <= 458.0)\n'
#  '     If (feature 5 <= 222.5)\n'
#  '      If (feature 7 <= 719.5)\n'
#  '       If (feature 4 <= 811.0)\n'
#  '        If (feature 13 <= 112.5)\n'
#  '         Predict: 2979862.362\n'
#  '        Else (feature 13 > 112.5)\n'
#  '         Predict: 3820840.679760003\n'
#  '       Else (feature 4 > 811.0)\n'
#  '        If (feature 5 <= 167.5)\n'
#  '         Predict: 4864631.850389611\n'
#  '        Else (feature 5 > 167.5)\n'
#  '         Predict: 6276497.534603174\n'
#  '      Else (feature 7 > 719.5)\n'
#  '       If (feature 12 <= 19177.0)\n'
#  '        If (feature 1 <= 594.5)\n'
#  '         Predict: 5922017.684\n'
#  '        Else (feature 1 > 594.5)\n'
#  '         Predict: 9269565.64\n'
#  '       Else (feature 12 > 19177.0)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 8535921.344\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 1.2129436036923077E7\n'
#  '     Else (feature 5 > 222.5)\n'
#  '      If (feature 3 <= 7334.5)\n'
#  '       If (feature 7 <= 835.5)\n'
#  '        If (feature 1 <= 297.5)\n'
#  '         Predict: 6132832.682763158\n'
#  '        Else (feature 1 > 297.5)\n'
#  '         Predict: 8054580.05017621\n'
#  '       Else (feature 7 > 835.5)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 9532598.70368421\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 1.2268653128888885E7\n'
#  '      Else (feature 3 > 7334.5)\n'
#  '       If (feature 15 in {0.0})\n'
#  '        If (feature 1 <= 1451.0)\n'
#  '         Predict: 9790697.771509433\n'
#  '        Else (feature 1 > 1451.0)\n'
#  '         Predict: 1.3938453691111108E7\n'
#  '       Else (feature 15 not in {0.0})\n'
#  '        If (feature 8 <= 19.75)\n'
#  '         Predict: 1.555490000375E7\n'
#  '        Else (feature 8 > 19.75)\n'
#  '         Predict: 1.263101345E7\n'
#  '    Else (feature 5 > 458.0)\n'
#  '     If (feature 7 <= 363.5)\n'
#  '      If (feature 10 <= 9.45)\n'
#  '       If (feature 4 <= 427.5)\n'
#  '        If (feature 1 <= 195.5)\n'
#  '         Predict: 2.0304029963333335E7\n'
#  '        Else (feature 1 > 195.5)\n'
#  '         Predict: 2.895065192E7\n'
#  '       Else (feature 4 > 427.5)\n'
#  '        If (feature 5 <= 749.0)\n'
#  '         Predict: 1.123420905689655E7\n'
#  '        Else (feature 5 > 749.0)\n'
#  '         Predict: 1.7620173486818183E7\n'
#  '      Else (feature 10 > 9.45)\n'
#  '       If (feature 13 <= 269.5)\n'
#  '        If (feature 7 <= 76.5)\n'
#  '         Predict: 1.137647686E7\n'
#  '        Else (feature 7 > 76.5)\n'
#  '         Predict: 8327091.191249999\n'
#  '       Else (feature 13 > 269.5)\n'
#  '        If (feature 1 <= 455.5)\n'
#  '         Predict: 9452193.2975\n'
#  '        Else (feature 1 > 455.5)\n'
#  '         Predict: 1.2080672340588238E7\n'
#  '     Else (feature 7 > 363.5)\n'
#  '      If (feature 5 <= 749.0)\n'
#  '       If (feature 7 <= 614.5)\n'
#  '        If (feature 5 <= 556.5)\n'
#  '         Predict: 1.1574441100588236E7\n'
#  '        Else (feature 5 > 556.5)\n'
#  '         Predict: 1.3667831403E7\n'
#  '       Else (feature 7 > 614.5)\n'
#  '        If (feature 4 <= 4352.0)\n'
#  '         Predict: 1.5049747844999999E7\n'
#  '        Else (feature 4 > 4352.0)\n'
#  '         Predict: 1.80621955815E7\n'
#  '      Else (feature 5 > 749.0)\n'
#  '       If (feature 1 <= 1030.0)\n'
#  '        If (feature 17 in {0.0})\n'
#  '         Predict: 1.8387398560434785E7\n'
#  '        Else (feature 17 not in {0.0})\n'
#  '         Predict: 2.7828975319999993E7\n'
#  '       Else (feature 1 > 1030.0)\n'
#  '        If (feature 0 <= 799.5)\n'
#  '         Predict: 2.3825506318125002E7\n'
#  '        Else (feature 0 > 799.5)\n'
#  '         Predict: 2.0932545184375003E7\n'
#  '  Tree 6 (weight 1.0):\n'
#  '    If (feature 5 <= 458.0)\n'
#  '     If (feature 1 <= 277.5)\n'
#  '      If (feature 5 <= 207.5)\n'
#  '       If (feature 4 <= 344.5)\n'
#  '        If (feature 5 <= 56.5)\n'
#  '         Predict: 1906907.5767741937\n'
#  '        Else (feature 5 > 56.5)\n'
#  '         Predict: 3046637.7197202784\n'
#  '       Else (feature 4 > 344.5)\n'
#  '        If (feature 7 <= 340.0)\n'
#  '         Predict: 3690397.2968627447\n'
#  '        Else (feature 7 > 340.0)\n'
#  '         Predict: 5426173.267399997\n'
#  '      Else (feature 5 > 207.5)\n'
#  '       If (feature 10 <= 6.75)\n'
#  '        If (feature 16 in {1.0})\n'
#  '         Predict: 5482376.0\n'
#  '        Else (feature 16 not in {1.0})\n'
#  '         Predict: 1.0892269282499999E7\n'
#  '       Else (feature 10 > 6.75)\n'
#  '        If (feature 8 <= 14.350000000000001)\n'
#  '         Predict: 8877798.493333332\n'
#  '        Else (feature 8 > 14.350000000000001)\n'
#  '         Predict: 5900674.016375001\n'
#  '     Else (feature 1 > 277.5)\n'
#  '      If (feature 5 <= 275.5)\n'
#  '       If (feature 7 <= 719.5)\n'
#  '        If (feature 4 <= 1430.5)\n'
#  '         Predict: 5478243.352826087\n'
#  '        Else (feature 4 > 1430.5)\n'
#  '         Predict: 7133321.1549295755\n'
#  '       Else (feature 7 > 719.5)\n'
#  '        If (feature 0 <= 317.0)\n'
#  '         Predict: 9132946.072058821\n'
#  '        Else (feature 0 > 317.0)\n'
#  '         Predict: 1.1634044166666662E7\n'
#  '      Else (feature 5 > 275.5)\n'
#  '       If (feature 7 <= 538.5)\n'
#  '        If (feature 0 <= 390.0)\n'
#  '         Predict: 8258509.135116279\n'
#  '        Else (feature 0 > 390.0)\n'
#  '         Predict: 9755742.284590162\n'
#  '       Else (feature 7 > 538.5)\n'
#  '        If (feature 1 <= 546.5)\n'
#  '         Predict: 9870469.454545455\n'
#  '        Else (feature 1 > 546.5)\n'
#  '         Predict: 1.3008506040000001E7\n'
#  '    Else (feature 5 > 458.0)\n'
#  '     If (feature 4 <= 3323.0)\n'
#  '      If (feature 5 <= 956.0)\n'
#  '       If (feature 7 <= 118.5)\n'
#  '        If (feature 5 <= 623.5)\n'
#  '         Predict: 8675412.4635\n'
#  '        Else (feature 5 > 623.5)\n'
#  '         Predict: 1.1125401590000004E7\n'
#  '       Else (feature 7 > 118.5)\n'
#  '        If (feature 8 <= 26.455)\n'
#  '         Predict: 1.4515617905000001E7\n'
#  '        Else (feature 8 > 26.455)\n'
#  '         Predict: 1.1702783456989247E7\n'
#  '      Else (feature 5 > 956.0)\n'
#  '       If (feature 1 <= 225.0)\n'
#  '        If (feature 1 <= 195.5)\n'
#  '         Predict: 2.0304029963333335E7\n'
#  '        Else (feature 1 > 195.5)\n'
#  '         Predict: 2.8202867519999996E7\n'
#  '       Else (feature 1 > 225.0)\n'
#  '        If (feature 12 <= 18397.0)\n'
#  '         Predict: 1.5475189285714287E7\n'
#  '        Else (feature 12 > 18397.0)\n'
#  '         Predict: 1.8760634893571433E7\n'
#  '     Else (feature 4 > 3323.0)\n'
#  '      If (feature 4 <= 5590.5)\n'
#  '       If (feature 5 <= 749.0)\n'
#  '        If (feature 10 <= 6.75)\n'
#  '         Predict: 2.006864396E7\n'
#  '        Else (feature 10 > 6.75)\n'
#  '         Predict: 1.3990621295E7\n'
#  '       Else (feature 5 > 749.0)\n'
#  '        If (feature 8 <= 105.875)\n'
#  '         Predict: 2.0331582114137933E7\n'
#  '        Else (feature 8 > 105.875)\n'
#  '         Predict: 1.5780556391111122E7\n'
#  '      Else (feature 4 > 5590.5)\n'
#  '       If (feature 2 <= 14255.5)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 1.7189784639999997E7\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 2.055715740714286E7\n'
#  '       Else (feature 2 > 14255.5)\n'
#  '        If (feature 9 <= 6.45)\n'
#  '         Predict: 2.1050794927916665E7\n'
#  '        Else (feature 9 > 6.45)\n'
#  '         Predict: 1.7438521345714305E7\n'
#  '  Tree 7 (weight 1.0):\n'
#  '    If (feature 4 <= 1737.0)\n'
#  '     If (feature 5 <= 318.0)\n'
#  '      If (feature 1 <= 159.5)\n'
#  '       If (feature 7 <= 452.5)\n'
#  '        If (feature 5 <= 90.5)\n'
#  '         Predict: 2269081.4374576276\n'
#  '        Else (feature 5 > 90.5)\n'
#  '         Predict: 3711354.91111111\n'
#  '       Else (feature 7 > 452.5)\n'
#  '        If (feature 0 <= 72.5)\n'
#  '         Predict: 3388363.5420000004\n'
#  '        Else (feature 0 > 72.5)\n'
#  '         Predict: 5490328.022352941\n'
#  '      Else (feature 1 > 159.5)\n'
#  '       If (feature 8 <= 24.155)\n'
#  '        If (feature 0 <= 153.5)\n'
#  '         Predict: 5457090.6742857145\n'
#  '        Else (feature 0 > 153.5)\n'
#  '         Predict: 7070472.466111108\n'
#  '       Else (feature 8 > 24.155)\n'
#  '        If (feature 5 <= 167.5)\n'
#  '         Predict: 4037424.3816763004\n'
#  '        Else (feature 5 > 167.5)\n'
#  '         Predict: 5745757.735828571\n'
#  '     Else (feature 5 > 318.0)\n'
#  '      If (feature 6 <= 8552.5)\n'
#  '       If (feature 4 <= 676.5)\n'
#  '        If (feature 12 <= 19406.5)\n'
#  '         Predict: 6140079.074285715\n'
#  '        Else (feature 12 > 19406.5)\n'
#  '         Predict: 7709513.7700000005\n'
#  '       Else (feature 4 > 676.5)\n'
#  '        If (feature 0 <= 189.0)\n'
#  '         Predict: 8733533.39\n'
#  '        Else (feature 0 > 189.0)\n'
#  '         Predict: 7562384.480000004\n'
#  '      Else (feature 6 > 8552.5)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 12 <= 19890.5)\n'
#  '         Predict: 8380982.232794118\n'
#  '        Else (feature 12 > 19890.5)\n'
#  '         Predict: 9969204.861\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 7 <= 254.0)\n'
#  '         Predict: 1.6949033323333334E7\n'
#  '        Else (feature 7 > 254.0)\n'
#  '         Predict: 2.7828975319999993E7\n'
#  '    Else (feature 4 > 1737.0)\n'
#  '     If (feature 1 <= 642.5)\n'
#  '      If (feature 4 <= 2296.5)\n'
#  '       If (feature 0 <= 213.5)\n'
#  '        If (feature 13 <= 269.5)\n'
#  '         Predict: 6977066.19\n'
#  '        Else (feature 13 > 269.5)\n'
#  '         Predict: 9661104.460000008\n'
#  '       Else (feature 0 > 213.5)\n'
#  '        If (feature 1 <= 594.5)\n'
#  '         Predict: 9056068.754285714\n'
#  '        Else (feature 1 > 594.5)\n'
#  '         Predict: 1.13530539E7\n'
#  '      Else (feature 4 > 2296.5)\n'
#  '       If (feature 7 <= 104.5)\n'
#  '        Predict: 1.896920124E7\n'
#  '       Else (feature 7 > 104.5)\n'
#  '        If (feature 4 <= 2587.0)\n'
#  '         Predict: 8394350.696842106\n'
#  '        Else (feature 4 > 2587.0)\n'
#  '         Predict: 1.0996522874705883E7\n'
#  '     Else (feature 1 > 642.5)\n'
#  '      If (feature 0 <= 573.5)\n'
#  '       If (feature 4 <= 3323.0)\n'
#  '        If (feature 5 <= 623.5)\n'
#  '         Predict: 1.024603059637681E7\n'
#  '        Else (feature 5 > 623.5)\n'
#  '         Predict: 1.5735678704499995E7\n'
#  '       Else (feature 4 > 3323.0)\n'
#  '        If (feature 6 <= 29188.5)\n'
#  '         Predict: 1.3517725320000002E7\n'
#  '        Else (feature 6 > 29188.5)\n'
#  '         Predict: 1.6927597298125E7\n'
#  '      Else (feature 0 > 573.5)\n'
#  '       If (feature 5 <= 623.5)\n'
#  '        If (feature 7 <= 719.5)\n'
#  '         Predict: 1.2592010145714289E7\n'
#  '        Else (feature 7 > 719.5)\n'
#  '         Predict: 1.58111449534375E7\n'
#  '       Else (feature 5 > 623.5)\n'
#  '        If (feature 10 <= 10.45)\n'
#  '         Predict: 2.1356914553928573E7\n'
#  '        Else (feature 10 > 10.45)\n'
#  '         Predict: 1.832885811130435E7\n'
#  '  Tree 8 (weight 1.0):\n'
#  '    If (feature 5 <= 318.0)\n'
#  '     If (feature 3 <= 5041.5)\n'
#  '      If (feature 2 <= 2832.5)\n'
#  '       If (feature 1 <= 131.5)\n'
#  '        If (feature 12 <= 18910.0)\n'
#  '         Predict: 2082939.2639215689\n'
#  '        Else (feature 12 > 18910.0)\n'
#  '         Predict: 3126603.1883464563\n'
#  '       Else (feature 1 > 131.5)\n'
#  '        If (feature 12 <= 19103.5)\n'
#  '         Predict: 3345282.0148076927\n'
#  '        Else (feature 12 > 19103.5)\n'
#  '         Predict: 4459517.779438202\n'
#  '      Else (feature 2 > 2832.5)\n'
#  '       If (feature 8 <= 24.155)\n'
#  '        If (feature 5 <= 146.5)\n'
#  '         Predict: 5508781.667857142\n'
#  '        Else (feature 5 > 146.5)\n'
#  '         Predict: 7735761.784038461\n'
#  '       Else (feature 8 > 24.155)\n'
#  '        If (feature 4 <= 811.0)\n'
#  '         Predict: 4003581.3428301886\n'
#  '        Else (feature 4 > 811.0)\n'
#  '         Predict: 5573186.516153848\n'
#  '     Else (feature 3 > 5041.5)\n'
#  '      If (feature 12 <= 21324.5)\n'
#  '       If (feature 2 <= 14255.5)\n'
#  '        If (feature 1 <= 425.5)\n'
#  '         Predict: 5478121.1162068965\n'
#  '        Else (feature 1 > 425.5)\n'
#  '         Predict: 7867295.562131145\n'
#  '       Else (feature 2 > 14255.5)\n'
#  '        If (feature 10 <= 9.149999999999999)\n'
#  '         Predict: 1.304344189E7\n'
#  '        Else (feature 10 > 9.149999999999999)\n'
#  '         Predict: 1.5727561240000002E7\n'
#  '      Else (feature 12 > 21324.5)\n'
#  '       If (feature 7 <= 1226.0)\n'
#  '        If (feature 3 <= 8011.5)\n'
#  '         Predict: 9259865.361363636\n'
#  '        Else (feature 3 > 8011.5)\n'
#  '         Predict: 1.1558815310000002E7\n'
#  '       Else (feature 7 > 1226.0)\n'
#  '        If (feature 5 <= 136.5)\n'
#  '         Predict: 1.114786541E7\n'
#  '        Else (feature 5 > 136.5)\n'
#  '         Predict: 1.4834164907142857E7\n'
#  '    Else (feature 5 > 318.0)\n'
#  '     If (feature 5 <= 623.5)\n'
#  '      If (feature 4 <= 2970.0)\n'
#  '       If (feature 1 <= 642.5)\n'
#  '        If (feature 11 <= 12.55)\n'
#  '         Predict: 8086461.397816094\n'
#  '        Else (feature 11 > 12.55)\n'
#  '         Predict: 9705674.223513514\n'
#  '       Else (feature 1 > 642.5)\n'
#  '        If (feature 7 <= 614.5)\n'
#  '         Predict: 1.05305866744E7\n'
#  '        Else (feature 7 > 614.5)\n'
#  '         Predict: 1.5023543819999993E7\n'
#  '      Else (feature 4 > 2970.0)\n'
#  '       If (feature 7 <= 987.5)\n'
#  '        If (feature 2 <= 16816.0)\n'
#  '         Predict: 1.1629333972413791E7\n'
#  '        Else (feature 2 > 16816.0)\n'
#  '         Predict: 1.5197179744285712E7\n'
#  '       Else (feature 7 > 987.5)\n'
#  '        If (feature 17 in {0.0})\n'
#  '         Predict: 1.540075117727273E7\n'
#  '        Else (feature 17 not in {0.0})\n'
#  '         Predict: 2.10741162675E7\n'
#  '     Else (feature 5 > 623.5)\n'
#  '      If (feature 4 <= 2970.0)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 0 <= 189.0)\n'
#  '         Predict: 1.0250469290000001E7\n'
#  '        Else (feature 0 > 189.0)\n'
#  '         Predict: 1.4142066344705882E7\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 4 <= 427.5)\n'
#  '         Predict: 2.5868852963333335E7\n'
#  '        Else (feature 4 > 427.5)\n'
#  '         Predict: 1.742957469466667E7\n'
#  '      Else (feature 4 > 2970.0)\n'
#  '       If (feature 6 <= 38629.0)\n'
#  '        If (feature 15 in {0.0})\n'
#  '         Predict: 1.5904174765999997E7\n'
#  '        Else (feature 15 not in {0.0})\n'
#  '         Predict: 1.883890314583333E7\n'
#  '       Else (feature 6 > 38629.0)\n'
#  '        If (feature 2 <= 14255.5)\n'
#  '         Predict: 1.37044496E7\n'
#  '        Else (feature 2 > 14255.5)\n'
#  '         Predict: 2.086164871418605E7\n'
#  '  Tree 9 (weight 1.0):\n'
#  '    If (feature 5 <= 296.5)\n'
#  '     If (feature 1 <= 297.5)\n'
#  '      If (feature 7 <= 719.5)\n'
#  '       If (feature 5 <= 102.5)\n'
#  '        If (feature 7 <= 289.5)\n'
#  '         Predict: 2463294.48\n'
#  '        Else (feature 7 > 289.5)\n'
#  '         Predict: 3537822.4048936153\n'
#  '       Else (feature 5 > 102.5)\n'
#  '        If (feature 7 <= 239.5)\n'
#  '         Predict: 4132766.631298701\n'
#  '        Else (feature 7 > 239.5)\n'
#  '         Predict: 5249405.281954023\n'
#  '      Else (feature 7 > 719.5)\n'
#  '       If (feature 5 <= 146.5)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 5935263.304285714\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 7895099.200000003\n'
#  '       Else (feature 5 > 146.5)\n'
#  '        If (feature 0 <= 176.5)\n'
#  '         Predict: 1.07047282575E7\n'
#  '        Else (feature 0 > 176.5)\n'
#  '         Predict: 7826438.5625\n'
#  '     Else (feature 1 > 297.5)\n'
#  '      If (feature 15 in {0.0})\n'
#  '       If (feature 4 <= 1587.5)\n'
#  '        If (feature 12 <= 21060.0)\n'
#  '         Predict: 5354933.0376767665\n'
#  '        Else (feature 12 > 21060.0)\n'
#  '         Predict: 6874645.716451614\n'
#  '       Else (feature 4 > 1587.5)\n'
#  '        If (feature 9 <= 2.8499999999999996)\n'
#  '         Predict: 9766591.69125\n'
#  '        Else (feature 9 > 2.8499999999999996)\n'
#  '         Predict: 7144453.044509804\n'
#  '      Else (feature 15 not in {0.0})\n'
#  '       If (feature 6 <= 20774.0)\n'
#  '        If (feature 8 <= 10.695)\n'
#  '         Predict: 1.2114010312E7\n'
#  '        Else (feature 8 > 10.695)\n'
#  '         Predict: 8141885.437380954\n'
#  '       Else (feature 6 > 20774.0)\n'
#  '        If (feature 4 <= 1737.0)\n'
#  '         Predict: 8315608.03\n'
#  '        Else (feature 4 > 1737.0)\n'
#  '         Predict: 1.1712691898E7\n'
#  '    Else (feature 5 > 296.5)\n'
#  '     If (feature 1 <= 642.5)\n'
#  '      If (feature 3 <= 2843.5)\n'
#  '       If (feature 11 <= 18.75)\n'
#  '        If (feature 2 <= 1950.5)\n'
#  '         Predict: 5752728.156666666\n'
#  '        Else (feature 2 > 1950.5)\n'
#  '         Predict: 7717265.8846875\n'
#  '       Else (feature 11 > 18.75)\n'
#  '        If (feature 15 in {1.0})\n'
#  '         Predict: 1.133505711E7\n'
#  '        Else (feature 15 not in {1.0})\n'
#  '         Predict: 1.4133369030000001E7\n'
#  '      Else (feature 3 > 2843.5)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 7 <= 719.5)\n'
#  '         Predict: 9490950.370914284\n'
#  '        Else (feature 7 > 719.5)\n'
#  '         Predict: 1.2603248895217387E7\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 4 <= 556.0)\n'
#  '         Predict: 2.857675972E7\n'
#  '        Else (feature 4 > 556.0)\n'
#  '         Predict: 1.8334376584666666E7\n'
#  '     Else (feature 1 > 642.5)\n'
#  '      If (feature 4 <= 3764.5)\n'
#  '       If (feature 6 <= 38629.0)\n'
#  '        If (feature 5 <= 749.0)\n'
#  '         Predict: 1.082948311926316E7\n'
#  '        Else (feature 5 > 749.0)\n'
#  '         Predict: 1.7155963113636352E7\n'
#  '       Else (feature 6 > 38629.0)\n'
#  '        If (feature 9 <= 5.05)\n'
#  '         Predict: 2.123272978E7\n'
#  '        Else (feature 9 > 5.05)\n'
#  '         Predict: 1.3216718278749999E7\n'
#  '      Else (feature 4 > 3764.5)\n'
#  '       If (feature 11 <= 10.55)\n'
#  '        If (feature 3 <= 13913.5)\n'
#  '         Predict: 1.2814648356666667E7\n'
#  '        Else (feature 3 > 13913.5)\n'
#  '         Predict: 8179767.269999996\n'
#  '       Else (feature 11 > 10.55)\n'
#  '        If (feature 2 <= 14255.5)\n'
#  '         Predict: 1.5743145275999999E7\n'
#  '        Else (feature 2 > 14255.5)\n'
#  '         Predict: 1.8765664034651164E7\n'
#  '  Tree 10 (weight 1.0):\n'
#  '    If (feature 4 <= 1587.5)\n'
#  '     If (feature 1 <= 277.5)\n'
#  '      If (feature 5 <= 207.5)\n'
#  '       If (feature 7 <= 363.5)\n'
#  '        If (feature 1 <= 131.5)\n'
#  '         Predict: 2708712.277245509\n'
#  '        Else (feature 1 > 131.5)\n'
#  '         Predict: 3806965.603687152\n'
#  '       Else (feature 7 > 363.5)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 4766259.03983871\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 9715199.744000006\n'
#  '      Else (feature 5 > 207.5)\n'
#  '       If (feature 5 <= 623.5)\n'
#  '        If (feature 7 <= 144.5)\n'
#  '         Predict: 5653205.990588236\n'
#  '        Else (feature 7 > 144.5)\n'
#  '         Predict: 6431123.006607144\n'
#  '       Else (feature 5 > 623.5)\n'
#  '        If (feature 17 in {0.0})\n'
#  '         Predict: 1.1101654883333333E7\n'
#  '        Else (feature 17 not in {0.0})\n'
#  '         Predict: 1.413336903E7\n'
#  '     Else (feature 1 > 277.5)\n'
#  '      If (feature 2 <= 6767.0)\n'
#  '       If (feature 12 <= 20800.0)\n'
#  '        If (feature 5 <= 296.5)\n'
#  '         Predict: 5466680.150360361\n'
#  '        Else (feature 5 > 296.5)\n'
#  '         Predict: 8236675.106981133\n'
#  '       Else (feature 12 > 20800.0)\n'
#  '        If (feature 11 <= 14.149999999999999)\n'
#  '         Predict: 7529511.8913513515\n'
#  '        Else (feature 11 > 14.149999999999999)\n'
#  '         Predict: 9341046.749999998\n'
#  '      Else (feature 2 > 6767.0)\n'
#  '       If (feature 0 <= 272.5)\n'
#  '        If (feature 4 <= 969.0)\n'
#  '         Predict: 5404413.784\n'
#  '        Else (feature 4 > 969.0)\n'
#  '         Predict: 7408894.15181818\n'
#  '       Else (feature 0 > 272.5)\n'
#  '        If (feature 5 <= 505.5)\n'
#  '         Predict: 8524278.901875\n'
#  '        Else (feature 5 > 505.5)\n'
#  '         Predict: 1.3109497355555555E7\n'
#  '    Else (feature 4 > 1587.5)\n'
#  '     If (feature 5 <= 623.5)\n'
#  '      If (feature 11 <= 18.75)\n'
#  '       If (feature 1 <= 707.5)\n'
#  '        If (feature 5 <= 318.0)\n'
#  '         Predict: 7250114.675606059\n'
#  '        Else (feature 5 > 318.0)\n'
#  '         Predict: 9934987.546944447\n'
#  '       Else (feature 1 > 707.5)\n'
#  '        If (feature 6 <= 45134.5)\n'
#  '         Predict: 1.054470036529412E7\n'
#  '        Else (feature 6 > 45134.5)\n'
#  '         Predict: 1.3378243440000007E7\n'
#  '      Else (feature 11 > 18.75)\n'
#  '       If (feature 5 <= 423.5)\n'
#  '        If (feature 2 <= 8378.5)\n'
#  '         Predict: 9710403.712727275\n'
#  '        Else (feature 2 > 8378.5)\n'
#  '         Predict: 1.208363095E7\n'
#  '       Else (feature 5 > 423.5)\n'
#  '        If (feature 15 in {0.0})\n'
#  '         Predict: 1.2760938775454545E7\n'
#  '        Else (feature 15 not in {0.0})\n'
#  '         Predict: 1.5160150254333338E7\n'
#  '     Else (feature 5 > 623.5)\n'
#  '      If (feature 1 <= 906.0)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 8 <= 77.905)\n'
#  '         Predict: 1.6608832331999999E7\n'
#  '        Else (feature 8 > 77.905)\n'
#  '         Predict: 1.3738984387272732E7\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 9 <= 4.55)\n'
#  '         Predict: 2.1934939796666667E7\n'
#  '        Else (feature 9 > 4.55)\n'
#  '         Predict: 1.6357609549E7\n'
#  '      Else (feature 1 > 906.0)\n'
#  '       If (feature 2 <= 14255.5)\n'
#  '        If (feature 9 <= 5.05)\n'
#  '         Predict: 1.878189617090909E7\n'
#  '        Else (feature 9 > 5.05)\n'
#  '         Predict: 1.359383328125E7\n'
#  '       Else (feature 2 > 14255.5)\n'
#  '        If (feature 11 <= 9.45)\n'
#  '         Predict: 3.170427334E7\n'
#  '        Else (feature 11 > 9.45)\n'
#  '         Predict: 2.089190563E7\n'
#  '  Tree 11 (weight 1.0):\n'
#  '    If (feature 5 <= 423.5)\n'
#  '     If (feature 4 <= 1326.5)\n'
#  '      If (feature 0 <= 134.5)\n'
#  '       If (feature 7 <= 289.5)\n'
#  '        If (feature 12 <= 19406.5)\n'
#  '         Predict: 2550695.28974359\n'
#  '        Else (feature 12 > 19406.5)\n'
#  '         Predict: 3665830.5555072455\n'
#  '       Else (feature 7 > 289.5)\n'
#  '        If (feature 1 <= 118.5)\n'
#  '         Predict: 3634090.5185714285\n'
#  '        Else (feature 1 > 118.5)\n'
#  '         Predict: 5183396.148571429\n'
#  '      Else (feature 0 > 134.5)\n'
#  '       If (feature 5 <= 207.5)\n'
#  '        If (feature 7 <= 424.5)\n'
#  '         Predict: 4146406.20572165\n'
#  '        Else (feature 7 > 424.5)\n'
#  '         Predict: 6516187.146857142\n'
#  '       Else (feature 5 > 207.5)\n'
#  '        If (feature 1 <= 277.5)\n'
#  '         Predict: 5900379.038928571\n'
#  '        Else (feature 1 > 277.5)\n'
#  '         Predict: 7012534.869452055\n'
#  '     Else (feature 4 > 1326.5)\n'
#  '      If (feature 7 <= 1226.0)\n'
#  '       If (feature 5 <= 296.5)\n'
#  '        If (feature 7 <= 538.5)\n'
#  '         Predict: 6751381.890574711\n'
#  '        Else (feature 7 > 538.5)\n'
#  '         Predict: 8642556.803269234\n'
#  '       Else (feature 5 > 296.5)\n'
#  '        If (feature 12 <= 21921.0)\n'
#  '         Predict: 9252770.886\n'
#  '        Else (feature 12 > 21921.0)\n'
#  '         Predict: 1.1131398305625E7\n'
#  '      Else (feature 7 > 1226.0)\n'
#  '       If (feature 2 <= 7788.0)\n'
#  '        If (feature 11 <= 19.65)\n'
#  '         Predict: 1.1315770552857144E7\n'
#  '        Else (feature 11 > 19.65)\n'
#  '         Predict: 1.3442650995000001E7\n'
#  '       Else (feature 2 > 7788.0)\n'
#  '        If (feature 3 <= 8011.5)\n'
#  '         Predict: 1.612870363E7\n'
#  '        Else (feature 3 > 8011.5)\n'
#  '         Predict: 1.5210225141428571E7\n'
#  '    Else (feature 5 > 423.5)\n'
#  '     If (feature 4 <= 3323.0)\n'
#  '      If (feature 5 <= 956.0)\n'
#  '       If (feature 4 <= 1326.5)\n'
#  '        If (feature 5 <= 623.5)\n'
#  '         Predict: 9222072.537\n'
#  '        Else (feature 5 > 623.5)\n'
#  '         Predict: 1.235635895375E7\n'
#  '       Else (feature 4 > 1326.5)\n'
#  '        If (feature 5 <= 623.5)\n'
#  '         Predict: 1.0783218722328767E7\n'
#  '        Else (feature 5 > 623.5)\n'
#  '         Predict: 1.3498601345806453E7\n'
#  '      Else (feature 5 > 956.0)\n'
#  '       If (feature 4 <= 556.0)\n'
#  '        If (feature 0 <= 163.5)\n'
#  '         Predict: 2.1545541985E7\n'
#  '        Else (feature 0 > 163.5)\n'
#  '         Predict: 2.7828975319999993E7\n'
#  '       Else (feature 4 > 556.0)\n'
#  '        If (feature 2 <= 14255.5)\n'
#  '         Predict: 1.6761993362857144E7\n'
#  '        Else (feature 2 > 14255.5)\n'
#  '         Predict: 2.1124991920000006E7\n'
#  '     Else (feature 4 > 3323.0)\n'
#  '      If (feature 5 <= 749.0)\n'
#  '       If (feature 7 <= 538.5)\n'
#  '        If (feature 12 <= 18560.5)\n'
#  '         Predict: 1.4768454565E7\n'
#  '        Else (feature 12 > 18560.5)\n'
#  '         Predict: 1.2580023764000004E7\n'
#  '       Else (feature 7 > 538.5)\n'
#  '        If (feature 6 <= 33731.5)\n'
#  '         Predict: 1.572387217214286E7\n'
#  '        Else (feature 6 > 33731.5)\n'
#  '         Predict: 1.91298597E7\n'
#  '      Else (feature 5 > 749.0)\n'
#  '       If (feature 2 <= 14255.5)\n'
#  '        If (feature 9 <= 5.05)\n'
#  '         Predict: 2.0000612414666668E7\n'
#  '        Else (feature 9 > 5.05)\n'
#  '         Predict: 1.4724502482857142E7\n'
#  '       Else (feature 2 > 14255.5)\n'
#  '        If (feature 11 <= 9.45)\n'
#  '         Predict: 3.170427334E7\n'
#  '        Else (feature 11 > 9.45)\n'
#  '         Predict: 2.205185763130435E7\n'
#  '  Tree 12 (weight 1.0):\n'
#  '    If (feature 5 <= 296.5)\n'
#  '     If (feature 15 in {0.0})\n'
#  '      If (feature 1 <= 277.5)\n'
#  '       If (feature 0 <= 115.5)\n'
#  '        If (feature 4 <= 208.5)\n'
#  '         Predict: 2135740.4295081967\n'
#  '        Else (feature 4 > 208.5)\n'
#  '         Predict: 3377568.865730338\n'
#  '       Else (feature 0 > 115.5)\n'
#  '        If (feature 5 <= 193.5)\n'
#  '         Predict: 3887698.389777778\n'
#  '        Else (feature 5 > 193.5)\n'
#  '         Predict: 5573566.114354836\n'
#  '      Else (feature 1 > 277.5)\n'
#  '       If (feature 5 <= 240.5)\n'
#  '        If (feature 5 <= 167.5)\n'
#  '         Predict: 4726632.015454546\n'
#  '        Else (feature 5 > 167.5)\n'
#  '         Predict: 6091306.324520548\n'
#  '       Else (feature 5 > 240.5)\n'
#  '        If (feature 7 <= 987.5)\n'
#  '         Predict: 7414331.149230768\n'
#  '        Else (feature 7 > 987.5)\n'
#  '         Predict: 1.4144052099999985E7\n'
#  '     Else (feature 15 not in {0.0})\n'
#  '      If (feature 2 <= 5472.0)\n'
#  '       If (feature 12 <= 24569.5)\n'
#  '        If (feature 7 <= 987.5)\n'
#  '         Predict: 6628545.1509374995\n'
#  '        Else (feature 7 > 987.5)\n'
#  '         Predict: 9345339.637\n'
#  '       Else (feature 12 > 24569.5)\n'
#  '        Predict: 1.1020194659999996E7\n'
#  '      Else (feature 2 > 5472.0)\n'
#  '       If (feature 8 <= 7.895)\n'
#  '        If (feature 2 <= 6767.0)\n'
#  '         Predict: 1.6669817800000003E7\n'
#  '        Else (feature 2 > 6767.0)\n'
#  '         Predict: 1.5547231899999999E7\n'
#  '       Else (feature 8 > 7.895)\n'
#  '        If (feature 6 <= 26319.0)\n'
#  '         Predict: 9033869.23647059\n'
#  '        Else (feature 6 > 26319.0)\n'
#  '         Predict: 1.171190745636364E7\n'
#  '    Else (feature 5 > 296.5)\n'
#  '     If (feature 3 <= 8011.5)\n'
#  '      If (feature 12 <= 20442.5)\n'
#  '       If (feature 2 <= 3400.5)\n'
#  '        If (feature 1 <= 455.5)\n'
#  '         Predict: 6763755.171666667\n'
#  '        Else (feature 1 > 455.5)\n'
#  '         Predict: 9530012.099999994\n'
#  '       Else (feature 2 > 3400.5)\n'
#  '        If (feature 0 <= 163.5)\n'
#  '         Predict: 1.7671692502499998E7\n'
#  '        Else (feature 0 > 163.5)\n'
#  '         Predict: 9154529.045840709\n'
#  '      Else (feature 12 > 20442.5)\n'
#  '       If (feature 5 <= 623.5)\n'
#  '        If (feature 11 <= 18.75)\n'
#  '         Predict: 9714664.375192307\n'
#  '        Else (feature 11 > 18.75)\n'
#  '         Predict: 1.1869740767352946E7\n'
#  '       Else (feature 5 > 623.5)\n'
#  '        If (feature 9 <= 2.55)\n'
#  '         Predict: 1.191309662E7\n'
#  '        Else (feature 9 > 2.55)\n'
#  '         Predict: 1.561729321E7\n'
#  '     Else (feature 3 > 8011.5)\n'
#  '      If (feature 7 <= 363.5)\n'
#  '       If (feature 4 <= 5590.5)\n'
#  '        If (feature 5 <= 458.0)\n'
#  '         Predict: 9147403.433809524\n'
#  '        Else (feature 5 > 458.0)\n'
#  '         Predict: 1.2800960725714283E7\n'
#  '       Else (feature 4 > 5590.5)\n'
#  '        If (feature 3 <= 13913.5)\n'
#  '         Predict: 1.762721757E7\n'
#  '        Else (feature 3 > 13913.5)\n'
#  '         Predict: 2.348151765E7\n'
#  '      Else (feature 7 > 363.5)\n'
#  '       If (feature 3 <= 11751.0)\n'
#  '        If (feature 2 <= 9861.5)\n'
#  '         Predict: 1.0013724616666667E7\n'
#  '        Else (feature 2 > 9861.5)\n'
#  '         Predict: 1.52671904371831E7\n'
#  '       Else (feature 3 > 11751.0)\n'
#  '        If (feature 12 <= 20800.0)\n'
#  '         Predict: 1.6890983287954547E7\n'
#  '        Else (feature 12 > 20800.0)\n'
#  '         Predict: 2.033166563964286E7\n'
#  '  Tree 13 (weight 1.0):\n'
#  '    If (feature 6 <= 24453.5)\n'
#  '     If (feature 5 <= 222.5)\n'
#  '      If (feature 5 <= 123.5)\n'
#  '       If (feature 0 <= 72.5)\n'
#  '        If (feature 1 <= 54.5)\n'
#  '         Predict: 1724011.9305882351\n'
#  '        Else (feature 1 > 54.5)\n'
#  '         Predict: 2689030.4112790693\n'
# ...
#  '        Else (feature 16 not in {1.0})\n'
#  '         Predict: 1.4678965401515154E7\n'
#  '      Else (feature 5 > 749.0)\n'
#  '       If (feature 7 <= 452.5)\n'
#  '        If (feature 11 <= 14.149999999999999)\n'
#  '         Predict: 1.803121701588235E7\n'
#  '        Else (feature 11 > 14.149999999999999)\n'
#  '         Predict: 1.5160705878999997E7\n'
#  '       Else (feature 7 > 452.5)\n'
#  '        If (feature 0 <= 573.5)\n'
#  '         Predict: 1.889455003142857E7\n'
#  '        Else (feature 0 > 573.5)\n'
#  '         Predict: 2.193872476E7\n'
#  '     Else (feature 3 > 11751.0)\n'
#  '      If (feature 5 <= 623.5)\n'
#  '       If (feature 12 <= 21060.0)\n'
#  '        If (feature 13 <= 1413.0)\n'
#  '         Predict: 1.3403698934333334E7\n'
#  '        Else (feature 13 > 1413.0)\n'
#  '         Predict: 1.0549958942222217E7\n'
#  '       Else (feature 12 > 21060.0)\n'
#  '        If (feature 12 <= 22366.0)\n'
#  '         Predict: 1.618474006857143E7\n'
#  '        Else (feature 12 > 22366.0)\n'
#  '         Predict: 1.86340835825E7\n'
#  '      Else (feature 5 > 623.5)\n'
#  '       If (feature 15 in {0.0})\n'
#  '        If (feature 12 <= 20597.5)\n'
#  '         Predict: 1.6782271121249996E7\n'
#  '        Else (feature 12 > 20597.5)\n'
#  '         Predict: 2.2011123083333332E7\n'
#  '       Else (feature 15 not in {0.0})\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 1.9501972490000002E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 2.4494562429090913E7\n'
#  '  Tree 16 (weight 1.0):\n'
#  '    If (feature 1 <= 642.5)\n'
#  '     If (feature 1 <= 195.5)\n'
#  '      If (feature 5 <= 366.5)\n'
#  '       If (feature 5 <= 102.5)\n'
#  '        If (feature 5 <= 40.5)\n'
#  '         Predict: 1733009.5344444446\n'
#  '        Else (feature 5 > 40.5)\n'
#  '         Predict: 2790973.9327419354\n'
#  '       Else (feature 5 > 102.5)\n'
#  '        If (feature 4 <= 483.5)\n'
#  '         Predict: 3987409.2469791663\n'
#  '        Else (feature 4 > 483.5)\n'
#  '         Predict: 4829349.610000001\n'
#  '      Else (feature 5 > 366.5)\n'
#  '       If (feature 3 <= 2666.0)\n'
#  '        Predict: 2.150157979E7\n'
#  '       Else (feature 3 > 2666.0)\n'
#  '        Predict: 1.9705255050000004E7\n'
#  '     Else (feature 1 > 195.5)\n'
#  '      If (feature 0 <= 317.0)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 7 <= 493.5)\n'
#  '         Predict: 5995864.872451922\n'
#  '        Else (feature 7 > 493.5)\n'
#  '         Predict: 8583657.31611111\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 4 <= 556.0)\n'
#  '         Predict: 2.827764596E7\n'
#  '        Else (feature 4 > 556.0)\n'
#  '         Predict: 1.8559606183333337E7\n'
#  '      Else (feature 0 > 317.0)\n'
#  '       If (feature 5 <= 505.5)\n'
#  '        If (feature 7 <= 1226.0)\n'
#  '         Predict: 8092451.637115385\n'
#  '        Else (feature 7 > 1226.0)\n'
#  '         Predict: 1.3616919649999997E7\n'
#  '       Else (feature 5 > 505.5)\n'
#  '        If (feature 8 <= 77.905)\n'
#  '         Predict: 2.0543906246250004E7\n'
#  '        Else (feature 8 > 77.905)\n'
#  '         Predict: 1.1620240369333334E7\n'
#  '    Else (feature 1 > 642.5)\n'
#  '     If (feature 2 <= 10759.5)\n'
#  '      If (feature 7 <= 1226.0)\n'
#  '       If (feature 8 <= 188.28)\n'
#  '        If (feature 9 <= 9.05)\n'
#  '         Predict: 1.1188832875454543E7\n'
#  '        Else (feature 9 > 9.05)\n'
#  '         Predict: 8015852.551739127\n'
#  '       Else (feature 8 > 188.28)\n'
#  '        If (feature 12 <= 21060.0)\n'
#  '         Predict: 1.0802357517499998E7\n'
#  '        Else (feature 12 > 21060.0)\n'
#  '         Predict: 1.8241535E7\n'
#  '      Else (feature 7 > 1226.0)\n'
#  '       If (feature 13 <= 327.5)\n'
#  '        If (feature 1 <= 707.5)\n'
#  '         Predict: 1.4792665699999997E7\n'
#  '        Else (feature 1 > 707.5)\n'
#  '         Predict: 1.6345004903333336E7\n'
#  '       Else (feature 13 > 327.5)\n'
#  '        If (feature 0 <= 340.5)\n'
#  '         Predict: 1.012753801E7\n'
#  '        Else (feature 0 > 340.5)\n'
#  '         Predict: 1.310424058E7\n'
#  '     Else (feature 2 > 10759.5)\n'
#  '      If (feature 4 <= 2970.0)\n'
#  '       If (feature 4 <= 2062.0)\n'
#  '        If (feature 5 <= 423.5)\n'
#  '         Predict: 9172847.394\n'
#  '        Else (feature 5 > 423.5)\n'
#  '         Predict: 1.2313963980000004E7\n'
#  '       Else (feature 4 > 2062.0)\n'
#  '        If (feature 11 <= 11.05)\n'
#  '         Predict: 1.1347764424999999E7\n'
#  '        Else (feature 11 > 11.05)\n'
#  '         Predict: 1.3499179019499997E7\n'
#  '      Else (feature 4 > 2970.0)\n'
#  '       If (feature 12 <= 21060.0)\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 1.434235987923077E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 2.330006615333333E7\n'
#  '       Else (feature 12 > 21060.0)\n'
#  '        If (feature 6 <= 29188.5)\n'
#  '         Predict: 1.31563518E7\n'
#  '        Else (feature 6 > 29188.5)\n'
#  '         Predict: 1.9486815640263155E7\n'
#  '  Tree 17 (weight 1.0):\n'
#  '    If (feature 2 <= 9161.0)\n'
#  '     If (feature 0 <= 153.5)\n'
#  '      If (feature 5 <= 155.5)\n'
#  '       If (feature 7 <= 397.5)\n'
#  '        If (feature 2 <= 1424.0)\n'
#  '         Predict: 2025126.0003225806\n'
#  '        Else (feature 2 > 1424.0)\n'
#  '         Predict: 3150681.6235087723\n'
#  '       Else (feature 7 > 397.5)\n'
#  '        If (feature 2 <= 1775.5)\n'
#  '         Predict: 4007583.964736842\n'
#  '        Else (feature 2 > 1775.5)\n'
#  '         Predict: 5681884.461923077\n'
#  '      Else (feature 5 > 155.5)\n'
#  '       If (feature 5 <= 393.5)\n'
#  '        If (feature 15 in {0.0})\n'
#  '         Predict: 5222190.516562501\n'
#  '        Else (feature 15 not in {0.0})\n'
#  '         Predict: 7223263.664166664\n'
#  '       Else (feature 5 > 393.5)\n'
#  '        If (feature 5 <= 749.0)\n'
#  '         Predict: 8229070.675714285\n'
#  '        Else (feature 5 > 749.0)\n'
#  '         Predict: 1.1256128413333334E7\n'
#  '     Else (feature 0 > 153.5)\n'
#  '      If (feature 4 <= 1326.5)\n'
#  '       If (feature 8 <= 113.89)\n'
#  '        If (feature 11 <= 17.85)\n'
#  '         Predict: 5647037.575583334\n'
#  '        Else (feature 11 > 17.85)\n'
#  '         Predict: 7166898.376296295\n'
#  '       Else (feature 8 > 113.89)\n'
#  '        If (feature 12 <= 16366.5)\n'
#  '         Predict: 1.5504590724444445E7\n'
#  '        Else (feature 12 > 16366.5)\n'
#  '         Predict: 6618003.680327867\n'
#  '      Else (feature 4 > 1326.5)\n'
#  '       If (feature 7 <= 1226.0)\n'
#  '        If (feature 17 in {1.0})\n'
#  '         Predict: 7377200.935111112\n'
#  '        Else (feature 17 not in {1.0})\n'
#  '         Predict: 9487144.487906978\n'
#  '       Else (feature 7 > 1226.0)\n'
#  '        If (feature 10 <= 6.75)\n'
#  '         Predict: 2.137802282E7\n'
#  '        Else (feature 10 > 6.75)\n'
#  '         Predict: 1.370770828222222E7\n'
#  '    Else (feature 2 > 9161.0)\n'
#  '     If (feature 6 <= 38629.0)\n'
#  '      If (feature 4 <= 3764.5)\n'
#  '       If (feature 3 <= 6701.0)\n'
#  '        If (feature 7 <= 239.5)\n'
#  '         Predict: 8345069.767142857\n'
#  '        Else (feature 7 > 239.5)\n'
#  '         Predict: 5724198.420000002\n'
#  '       Else (feature 3 > 6701.0)\n'
#  '        If (feature 12 <= 19890.5)\n'
#  '         Predict: 1.0286081192424243E7\n'
#  '        Else (feature 12 > 19890.5)\n'
#  '         Predict: 1.3277226748085104E7\n'
#  '      Else (feature 4 > 3764.5)\n'
#  '       If (feature 3 <= 11751.0)\n'
#  '        If (feature 5 <= 749.0)\n'
#  '         Predict: 1.3486892955185186E7\n'
#  '        Else (feature 5 > 749.0)\n'
#  '         Predict: 1.8508739842499994E7\n'
#  '       Else (feature 3 > 11751.0)\n'
#  '        If (feature 12 <= 21692.0)\n'
#  '         Predict: 1.6334053705E7\n'
#  '        Else (feature 12 > 21692.0)\n'
#  '         Predict: 2.2185863340000004E7\n'
#  '     Else (feature 6 > 38629.0)\n'
#  '      If (feature 4 <= 5590.5)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 12 <= 18191.5)\n'
#  '         Predict: 1.2899197170625E7\n'
#  '        Else (feature 12 > 18191.5)\n'
#  '         Predict: 1.5570723992499992E7\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 7 <= 614.5)\n'
#  '         Predict: 2.296425293125E7\n'
#  '        Else (feature 7 > 614.5)\n'
#  '         Predict: 3.1704273340000004E7\n'
#  '      Else (feature 4 > 5590.5)\n'
#  '       If (feature 8 <= 43.644999999999996)\n'
#  '        If (feature 9 <= 3.8499999999999996)\n'
#  '         Predict: 2.7768203E7\n'
#  '        Else (feature 9 > 3.8499999999999996)\n'
#  '         Predict: 2.5092187886666667E7\n'
#  '       Else (feature 8 > 43.644999999999996)\n'
#  '        If (feature 1 <= 1451.0)\n'
#  '         Predict: 1.64399827425E7\n'
#  '        Else (feature 1 > 1451.0)\n'
#  '         Predict: 2.085738426384616E7\n'
#  '  Tree 18 (weight 1.0):\n'
#  '    If (feature 0 <= 340.5)\n'
#  '     If (feature 1 <= 258.5)\n'
#  '      If (feature 5 <= 423.5)\n'
#  '       If (feature 1 <= 159.5)\n'
#  '        If (feature 1 <= 80.5)\n'
#  '         Predict: 2281380.625479452\n'
#  '        Else (feature 1 > 80.5)\n'
#  '         Predict: 3410671.6892924528\n'
#  '       Else (feature 1 > 159.5)\n'
#  '        If (feature 5 <= 193.5)\n'
#  '         Predict: 3956860.5987581694\n'
#  '        Else (feature 5 > 193.5)\n'
#  '         Predict: 6256134.73054054\n'
#  '      Else (feature 5 > 423.5)\n'
#  '       If (feature 9 <= 5.35)\n'
#  '        If (feature 0 <= 143.5)\n'
#  '         Predict: 1.137647686E7\n'
#  '        Else (feature 0 > 143.5)\n'
#  '         Predict: 1.4133369030000001E7\n'
#  '       Else (feature 9 > 5.35)\n'
#  '        Predict: 2.782897532E7\n'
#  '     Else (feature 1 > 258.5)\n'
#  '      If (feature 5 <= 423.5)\n'
#  '       If (feature 7 <= 493.5)\n'
#  '        If (feature 9 <= 8.149999999999999)\n'
#  '         Predict: 6222193.169774011\n'
#  '        Else (feature 9 > 8.149999999999999)\n'
#  '         Predict: 4269789.996764709\n'
#  '       Else (feature 7 > 493.5)\n'
#  '        If (feature 8 <= 19.75)\n'
#  '         Predict: 9888728.93264706\n'
#  '        Else (feature 8 > 19.75)\n'
#  '         Predict: 8124822.801025638\n'
#  '      Else (feature 5 > 423.5)\n'
#  '       If (feature 1 <= 455.5)\n'
#  '        If (feature 11 <= 11.25)\n'
#  '         Predict: 8780352.035666667\n'
#  '        Else (feature 11 > 11.25)\n'
#  '         Predict: 1.163975077777778E7\n'
#  '       Else (feature 1 > 455.5)\n'
#  '        If (feature 2 <= 3627.0)\n'
#  '         Predict: 1.940211904E7\n'
#  '        Else (feature 2 > 3627.0)\n'
#  '         Predict: 1.2480090227E7\n'
#  '    Else (feature 0 > 340.5)\n'
#  '     If (feature 6 <= 38629.0)\n'
#  '      If (feature 3 <= 6701.0)\n'
#  '       If (feature 9 <= 3.75)\n'
#  '        If (feature 17 in {0.0})\n'
#  '         Predict: 1.0626440707419356E7\n'
#  '        Else (feature 17 not in {0.0})\n'
#  '         Predict: 1.9434425846666675E7\n'
#  '       Else (feature 9 > 3.75)\n'
#  '        If (feature 12 <= 18191.5)\n'
#  '         Predict: 7040639.075499999\n'
#  '        Else (feature 12 > 18191.5)\n'
#  '         Predict: 8988993.492909089\n'
#  '      Else (feature 3 > 6701.0)\n'
#  '       If (feature 5 <= 556.5)\n'
#  '        If (feature 7 <= 835.5)\n'
#  '         Predict: 9696682.022956524\n'
#  '        Else (feature 7 > 835.5)\n'
#  '         Predict: 1.4073758149166664E7\n'
#  '       Else (feature 5 > 556.5)\n'
#  '        If (feature 6 <= 26319.0)\n'
#  '         Predict: 1.4591728766521739E7\n'
#  '        Else (feature 6 > 26319.0)\n'
#  '         Predict: 1.767413599162162E7\n'
#  '     Else (feature 6 > 38629.0)\n'
#  '      If (feature 5 <= 956.0)\n'
#  '       If (feature 4 <= 4352.0)\n'
#  '        If (feature 1 <= 1451.0)\n'
#  '         Predict: 1.1761989011363637E7\n'
#  '        Else (feature 1 > 1451.0)\n'
#  '         Predict: 1.6128137512222223E7\n'
#  '       Else (feature 4 > 4352.0)\n'
#  '        If (feature 8 <= 68.39)\n'
#  '         Predict: 1.879315860105263E7\n'
#  '        Else (feature 8 > 68.39)\n'
#  '         Predict: 1.495458485526316E7\n'
#  '      Else (feature 5 > 956.0)\n'
#  '       If (feature 8 <= 43.644999999999996)\n'
#  '        If (feature 9 <= 3.8499999999999996)\n'
#  '         Predict: 2.7768203E7\n'
#  '        Else (feature 9 > 3.8499999999999996)\n'
#  '         Predict: 3.1704273340000004E7\n'
#  '       Else (feature 8 > 43.644999999999996)\n'
#  '        If (feature 7 <= 397.5)\n'
#  '         Predict: 2.178408025E7\n'
#  '        Else (feature 7 > 397.5)\n'
#  '         Predict: 2.3795078991538465E7\n'
#  '  Tree 19 (weight 1.0):\n'
#  '    If (feature 4 <= 1587.5)\n'
#  '     If (feature 1 <= 178.5)\n'
#  '      If (feature 1 <= 80.5)\n'
#  '       If (feature 16 in {0.0})\n'
#  '        If (feature 17 in {0.0})\n'
#  '         Predict: 1204230.947142857\n'
#  '        Else (feature 17 not in {0.0})\n'
#  '         Predict: 2130841.48125\n'
#  '       Else (feature 16 not in {0.0})\n'
#  '        If (feature 4 <= 311.5)\n'
#  '         Predict: 2667705.7720588236\n'
#  '        Else (feature 4 > 311.5)\n'
#  '         Predict: 4174100.504999999\n'
#  '      Else (feature 1 > 80.5)\n'
#  '       If (feature 12 <= 16399.0)\n'
#  '        If (feature 7 <= 131.5)\n'
#  '         Predict: 1994833.097142857\n'
#  '        Else (feature 7 > 131.5)\n'
#  '         Predict: 4142666.9933333346\n'
#  '       Else (feature 12 > 16399.0)\n'
#  '        If (feature 5 <= 167.5)\n'
#  '         Predict: 3465216.0847398844\n'
#  '        Else (feature 5 > 167.5)\n'
#  '         Predict: 4993647.1862222245\n'
#  '     Else (feature 1 > 178.5)\n'
#  '      If (feature 5 <= 956.0)\n'
#  '       If (feature 1 <= 368.5)\n'
#  '        If (feature 15 in {0.0})\n'
#  '         Predict: 5423974.955427629\n'
#  '        Else (feature 15 not in {0.0})\n'
#  '         Predict: 7320633.7749999985\n'
#  '       Else (feature 1 > 368.5)\n'
#  '        If (feature 4 <= 676.5)\n'
#  '         Predict: 4853811.581538462\n'
#  '        Else (feature 4 > 676.5)\n'
#  '         Predict: 7870383.493612905\n'
#  '      Else (feature 5 > 956.0)\n'
#  '       If (feature 12 <= 18910.0)\n'
#  '        If (feature 1 <= 225.0)\n'
#  '         Predict: 2.3897608374E7\n'
#  '        Else (feature 1 > 225.0)\n'
#  '         Predict: 1.4308283340000004E7\n'
#  '       Else (feature 12 > 18910.0)\n'
#  '        If (feature 11 <= 12.05)\n'
#  '         Predict: 1.632728461E7\n'
#  '        Else (feature 11 > 12.05)\n'
#  '         Predict: 1.7190570539999995E7\n'
#  '    Else (feature 4 > 1587.5)\n'
#  '     If (feature 2 <= 10759.5)\n'
#  '      If (feature 0 <= 340.5)\n'
#  '       If (feature 5 <= 956.0)\n'
#  '        If (feature 5 <= 366.5)\n'
#  '         Predict: 8264248.559285715\n'
#  '        Else (feature 5 > 366.5)\n'
#  '         Predict: 1.0754546322380949E7\n'
#  '       Else (feature 5 > 956.0)\n'
#  '        If (feature 1 <= 368.5)\n'
#  '         Predict: 2.21609634E7\n'
#  '        Else (feature 1 > 368.5)\n'
#  '         Predict: 1.8273339747500002E7\n'
#  '      Else (feature 0 > 340.5)\n'
#  '       If (feature 12 <= 20800.0)\n'
#  '        If (feature 5 <= 556.5)\n'
#  '         Predict: 8900746.924561404\n'
#  '        Else (feature 5 > 556.5)\n'
#  '         Predict: 1.3277121362105256E7\n'
#  '       Else (feature 12 > 20800.0)\n'
#  '        If (feature 5 <= 556.5)\n'
#  '         Predict: 1.1354366692777777E7\n'
#  '        Else (feature 5 > 556.5)\n'
#  '         Predict: 1.6362631976249998E7\n'
#  '     Else (feature 2 > 10759.5)\n'
#  '      If (feature 4 <= 4352.0)\n'
#  '       If (feature 12 <= 20800.0)\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 1.1913746901466666E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 2.3909319663333338E7\n'
#  '       Else (feature 12 > 20800.0)\n'
#  '        If (feature 5 <= 556.5)\n'
#  '         Predict: 1.302301067375E7\n'
#  '        Else (feature 5 > 556.5)\n'
#  '         Predict: 2.0880210791333333E7\n'
#  '      Else (feature 4 > 4352.0)\n'
#  '       If (feature 1 <= 1168.0)\n'
#  '        If (feature 10 <= 10.149999999999999)\n'
#  '         Predict: 1.6629654771818183E7\n'
#  '        Else (feature 10 > 10.149999999999999)\n'
#  '         Predict: 1.312215815333333E7\n'
#  '       Else (feature 1 > 1168.0)\n'
#  '        If (feature 5 <= 956.0)\n'
#  '         Predict: 1.8399807634117644E7\n'
#  '        Else (feature 5 > 956.0)\n'
#  '         Predict: 2.4330441646249995E7\n')

# %% [markdown]
# <h1 align="center">VORHERSAGE</h1>

# %%
hh_1_4_median = prediction_data_set.approxQuantile("HH_1_4", [0.5], 0)[0]
prediction = model.transform(prediction_data_set.fillna(hh_1_4_median, subset=["HH_1_4"]))
print(prediction.count())
prediction.select("prediction", "features").show(5)
prediction.select("prediction").collect()


prediction.toPandas().sort_values(by=["prediction"]).reset_index().plot(title="predicted " + pred_col, y=["prediction"])
